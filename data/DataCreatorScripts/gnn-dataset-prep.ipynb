# %% [markdown]
# <h1>Import All the necessary libs

# %%
import torch
from transformers import AutoTokenizer, AutoModelForTokenClassification, AutoConfig, pipeline
from tqdm import tqdm_notebook
import json
import spacy

# %% [markdown]
# <h1>Loading the dataset

# %%
path = "/kaggle/input/text-corpus-dataset/Biology_Full.json"
with open(path) as f:
    data = json.load(f)
chunks = [value['text'] for value in data.values()]
print("Total chunks: ", len(chunks))
# Out:
# Total chunks:  4348

# %%
for chunk in chunks:
    if len(chunk)>1024:
        print(len(chunk))
# Out:
# 1620
# 1620
# 1050
# 1050

# %%
def segment_text(text, maxLen):
    currLen = 0
    chunks = []
    currText = ""
    words = text.split()
    for word in words:
        if currLen + len(word) + (1 if currText else 0) <= maxLen:
            currText += " "+word
            currLen += len(word) + 1
        else:
            
            chunks.append(currText)
            currLen = len(word)
            currText = word
    if currText:
        chunks.append(currText) 
    return chunks

# %%
chunksT = []
for chu in chunks:
    # chunksT.extend(segment_text(chu, 512))
    chunksT.extend(segment_text(chu, 512))
print(len(chunksT))
print(chunksT[0])
# Out:
# 10587
#  Code, start stop codons and ultimate condition for cel division About the o rigin of the genetic c ode, the start and stop codons and the very first cell. Correspond ing author : Pierre F . Zöfel AEG Brussel retired Tel +3223806682 +32473/777801 Email; pierre.zofel@gmail.com/pierre.zofel@hotmail.com “The universality of the code argues that it must have been established very early in evolution. Originally , there may have been a stereochemical relationship between amino acids and the codons representing

# %%
chunksT[1]
# Out:
# 'them” Benjamin Lewin Abbreviations: AAs; amino acids AAi: binding amino acids AAx: recognized amino acid Bi 1-3: codon Code, start stop codons and ultimate condition for cel division Abstract : In the world of living organisms, a few important molecules play prominent role s. They are grouped together under two categories: the bases and the amino acids (AAs) , both of which have the common property of forming long chains containing multiple repetitions of the same elements . The living world constantly'

# %% [markdown]
# <h1>Extracting the entities with the labels

# %% [markdown]
# <h2>Using LLM

# %%
# def extract_entities(chunks, model_name="dbmdz/bert-large-cased-finetuned-conll03-english"):
#     try:
#         tokenizer = AutoTokenizer.from_pretrained(model_name)
#         model = AutoModelForTokenClassification.from_pretrained(model_name)
#         config = AutoConfig.from_pretrained(model_name)
        
#         inputs = tokenizer(chunks, return_tensors="pt", max_length=1024, padding=True, truncation=True)

#         with torch.no_grad():
#             outputs = model(**inputs)
#         predictions = torch.argmax(outputs.logits, dim=2)

#         tokens = tokenizer.convert_ids_to_tokens(inputs["input_ids"][0])
#         token_labels = [config.id2label[p.item()] for p in predictions[0]]

#         results = []
#         current_entity = []
#         current_label = None

#         for token, label in zip(tokens[1:-1], token_labels[1:-1]):
#             # Handle subwords
#             if token.startswith("##"):
#                 if current_entity:
#                     current_entity[-1] += token[2:]
#                 continue
                
#             # Handle entity continuation
#             if label.startswith("B-") or label == "O":
#                 if current_entity:
#                     results.append((" ".join(current_entity), current_label))
#                     current_entity = []
#                 # Remove B- prefix
#                 if label != "O":
#                     current_entity = [token]
#                     current_label = label[2:]
#             elif label.startswith("I-"):
#                 if not current_entity:
#                     current_entity = [token]
#                     current_label = label[2:]
#                 else:
#                     current_entity.append(token)
        
#         # Add final entity if exists
#         if current_entity:
#             results.append((" ".join(current_entity), current_label))
            
#         return results
        
#     except Exception as e:
#         print(f"Error performing NER: {str(e)}")
#         return []

# %%
# Entities_data = extract_entities(chunksT, model_name="dbmdz/bert-large-cased-finetuned-conll03-english")
# uncased_entites = [entities[0].lower().replace(" ", "").strip() for entities in Entities_data]

# %%
# uncased_entites

# %% [markdown]
# <h2>Using NLTK and spacy

# %%
def extract_nlp(chunks):
    nlp = spacy.load("en_core_web_sm")
    entities = []
    for chu in tqdm_notebook(chunks, total = len(chunks), desc = "process chunks"):
        doc = nlp(chu)
        for ent in doc.ents:
            entities.append([ent.text, ent.label_])
    return entities

# %%
entities = extract_nlp(chunks)
# Out:
# <ipython-input-10-95192a71d475>:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for chu in tqdm_notebook(chunks, total = len(chunks), desc = "process chunks"):
# process chunks:   0%|          | 0/4348 [00:00<?, ?it/s]

# %%
entities[3]
# Out:
# ['Benjamin Lewin Abbreviations', 'PERSON']

# %%
originalEntities = [ent[0] for ent in entities]

# %%
entityType_dict = {ent[0].lower().replace(" ", "").strip():ent[1] for ent in entities}
# entityType_dict

# %%
uncased_entites_ = [ent[0].lower().replace(" ", "").strip() for ent in entities]
print(len(uncased_entites_))
uncased_entites_[3]
# Out:
# 77306
# 'benjaminlewinabbreviations'

# %% [markdown]
# <h1>Extracting the Relations with the labels

# %%
def extract_triplets(text):
    triplets = []
    relation, subject, relation, object_ = '', '', '', ''
    text = text.strip()
    current = 'x'
    for token in text.replace("<s>", "").replace("<pad>", "").replace("</s>", "").split():
        if token == "<triplet>":
            current = 't'
            if relation != '':
                triplets.append({'head': subject.strip(), 'type': relation.strip(),'tail': object_.strip()})
                relation = ''
            subject = ''
        elif token == "<subj>":
            current = 's'
            if relation != '':
                triplets.append({'head': subject.strip(), 'type': relation.strip(),'tail': object_.strip()})
            object_ = ''
        elif token == "<obj>":
            current = 'o'
            relation = ''
        else:
            if current == 't':
                subject += ' ' + token
            elif current == 's':
                object_ += ' ' + token
            elif current == 'o':
                relation += ' ' + token
    if subject != '' and relation != '' and object_ != '':
        triplets.append({'head': subject.strip(), 'type': relation.strip(),'tail': object_.strip()})
    return triplets

# %%
triplet_extractor = pipeline('text2text-generation', model='Babelscape/rebel-large', tokenizer='Babelscape/rebel-large')
# Out:
# config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.23k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/344 [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
outputs = triplet_extractor(chunksT, return_tensors=True, return_text=False,  truncation=True, max_length=1024)

# %%
extracted_texts = triplet_extractor.tokenizer.batch_decode([output["generated_token_ids"] for output in outputs])

# %%
Relation_data = [extract_triplets(ext_text) for ext_text in extracted_texts]

# %% [markdown]
# <h1>Filtering the Relations and Entites by finding the common entities between both the data

# %%
final_res = []
for re_elements in Relation_data:
    for re in re_elements:
        if re['head'].lower().replace(" ", "").strip() in uncased_entites_ and re['tail'].lower().replace(" ", "").strip() in uncased_entites_:
            final_res.append({
                'head': re['head'],
                'tail': re['tail'],
                'relation': re['type']
            })
print(len(final_res))
# Out:
# 2772

# %%
final_res = list({tuple(d.items()): d for d in final_res}.values())
print(len(final_res))
final_res
# Out:
# 1592
# [{'head': 'binding', 'tail': 'binding', 'relation': 'use'},
#  {'head': 'molecule', 'tail': 'RNA', 'relation': 'has part'},
#  {'head': 'RNA', 'tail': 'nucleotide', 'relation': 'has part'},
#  {'head': 'Mohamed A. Marahiel',
#   'tail': 'Philipps University',
#   'relation': 'employer'},
#  {'head': 'recognition', 'tail': 'recognition', 'relation': 'instance of'},
#  {'head': 'ATP', 'tail': 'biochemistry', 'relation': 'studied by'},
#  {'head': 'biochemistry', 'tail': 'ATP', 'relation': 'studies'},
#  {'head': 'Nature 395', 'tail': 'Nature 418', 'relation': 'followed by'},
#  {'head': 'Bioessays', 'tail': 'USA', 'relation': 'country of origin'},
#  {'head': 'Marahiel MA', 'tail': 'Biochemistry', 'relation': 'field of work'},
#  {'head': 'Warsaw', 'tail': 'Ukraine', 'relation': 'country'},
#  {'head': 'Ukraine',
#   'tail': 'Warsaw',
#   'relation': 'contains administrative territorial entity'},
#  {'head': 'titin', 'tail': 'domain', 'relation': 'instance of'},
#  {'head': 'DDFLN4', 'tail': 'domain', 'relation': 'instance of'},
#  {'head': 'force', 'tail': 'force', 'relation': 'subclass of'},
#  {'head': 'DDFLN4', 'tail': 'I27', 'relation': 'part of'},
#  {'head': 'DDFLN4', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': '0', 'tail': '0', 'relation': 'point in time'},
#  {'head': 'FEL', 'tail': 'protein', 'relation': 'subclass of'},
#  {'head': 'CPU', 'tail': 'CPU', 'relation': 'has part'},
#  {'head': 'CPU', 'tail': 'CPU', 'relation': 'part of'},
#  {'head': 'I27', 'tail': 'Go model', 'relation': 'instance of'},
#  {'head': 'DDFLN4', 'tail': 'Go model', 'relation': 'instance of'},
#  {'head': 'Science', 'tail': 'Natl.', 'relation': 'part of'},
#  {'head': 'Natl.', 'tail': 'Science', 'relation': 'has part'},
#  {'head': 'DDFLN4', 'tail': 'PDB', 'relation': 'part of'},
#  {'head': 'capsid', 'tail': 'protein', 'relation': 'subclass of'},
#  {'head': 'cap', 'tail': 'capsid', 'relation': 'part of'},
#  {'head': 'capsid', 'tail': 'cap', 'relation': 'has part'},
#  {'head': 'binding', 'tail': 'binding', 'relation': 'has cause'},
#  {'head': 'binding', 'tail': 'binding', 'relation': 'has effect'},
#  {'head': '1', 'tail': '10', 'relation': 'number of participants'},
#  {'head': 'kas', 'tail': 'σc', 'relation': 'has part'},
#  {'head': 'capsid', 'tail': 'nucleation', 'relation': 'has part'},
#  {'head': 'nucleation', 'tail': 'capsid', 'relation': 'part of'},
#  {'head': 'protein', 'tail': 'protein', 'relation': 'subclass of'},
#  {'head': 'capsid', 'tail': 'proteins', 'relation': 'part of'},
#  {'head': 'proteins', 'tail': 'capsid', 'relation': 'has part'},
#  {'head': 'kBT', 'tail': '1', 'relation': 'point in time'},
#  {'head': '77', 'tail': '77', 'relation': 'point in time'},
#  {'head': 'Gregg Lois', 'tail': 'Yale University', 'relation': 'educated at'},
#  {'head': 'Minima', 'tail': 'Minima', 'relation': 'different from'},
#  {'head': 'T2', 'tail': 'T3', 'relation': 'followed by'},
#  {'head': 'T3', 'tail': 'T2', 'relation': 'follows'},
#  {'head': 'T3', 'tail': 'T4', 'relation': 'followed by'},
#  {'head': 'T4', 'tail': 'T3', 'relation': 'follows'},
#  {'head': 'minima', 'tail': 'minima', 'relation': 'subclass of'},
#  {'head': '3', 'tail': '3', 'relation': 'point in time'},
#  {'head': 'Nature', 'tail': 'journal', 'relation': 'instance of'},
#  {'head': 'Oxford University Press',
#   'tail': 'Oxford',
#   'relation': 'headquarters location'},
#  {'head': 'Utrecht University',
#   'tail': 'Utrecht',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'Utrecht University',
#   'tail': 'The Netherlands',
#   'relation': 'country'},
#  {'head': 'Utrecht', 'tail': 'The Netherlands', 'relation': 'country'},
#  {'head': 'Normal mode analysis', 'tail': 'protein', 'relation': 'studies'},
#  {'head': 'protein', 'tail': 'Normal mode analysis', 'relation': 'studied by'},
#  {'head': 'Viral Tiling Theory', 'tail': 'viral', 'relation': 'facet of'},
#  {'head': 'VIPER', 'tail': 'Protein Data Bank', 'relation': 'part of'},
#  {'head': 'capsid', 'tail': 'proteins', 'relation': 'subclass of'},
#  {'head': 'capsid', 'tail': 'protein', 'relation': 'part of'},
#  {'head': 'protein', 'tail': 'capsid', 'relation': 'has part'},
#  {'head': 'Hessian', 'tail': 'Fij', 'relation': 'has part'},
#  {'head': 'protein', 'tail': 'capsid', 'relation': 'part of'},
#  {'head': 'capsid', 'tail': 'protein', 'relation': 'has part'},
#  {'head': 'HK97', 'tail': 'capsid', 'relation': 'subclass of'},
#  {'head': 'RYMV', 'tail': 'capsid', 'relation': 'subclass of'},
#  {'head': 'HK97', 'tail': 'viral capsids', 'relation': 'instance of'},
#  {'head': 'capsid', 'tail': 'capsid', 'relation': 'different from'},
#  {'head': 'RYMV', 'tail': 'normal mode analysis', 'relation': 'instance of'},
#  {'head': 'HK97', 'tail': 'normal mode analysis', 'relation': 'instance of'},
#  {'head': 'comparison', 'tail': 'comparison', 'relation': 'subclass of'},
#  {'head': 'proteins', 'tail': 'capsid', 'relation': 'part of'},
#  {'head': 'capsid', 'tail': 'proteins', 'relation': 'has part'},
#  {'head': 'RNA', 'tail': 'capsid', 'relation': 'part of'},
#  {'head': 'capsid', 'tail': 'RNA', 'relation': 'has part'},
#  {'head': '1984', 'tail': '1984', 'relation': 'point in time'},
#  {'head': 'Lecce', 'tail': 'Italy', 'relation': 'country'},
#  {'head': 'speciﬁc', 'tail': 'ligand', 'relation': 'subclass of'},
#  {'head': '10', 'tail': '10', 'relation': 'point in time'},
#  {'head': 'A. Warshel', 'tail': 'Bioinformatics', 'relation': 'field of work'},
#  {'head': 'triangle',
#   'tail': 'pentagon',
#   'relation': 'has parts of the class'},
#  {'head': 'triangle', 'tail': 've', 'relation': 'has parts of the class'},
#  {'head': 'pentagon', 'tail': 'triangle', 'relation': 'part of'},
#  {'head': 've', 'tail': 'pentagon', 'relation': 'part of'},
#  {'head': 'seven', 'tail': 'seven', 'relation': 'number of episodes'},
#  {'head': 'EPSRC Advanced Research Fellowship',
#   'tail': 'EPSRC',
#   'relation': 'conferred by'},
#  {'head': 'P.S.', 'tail': 'American', 'relation': 'country'},
#  {'head': 'complex', 'tail': 'protein', 'relation': 'has part'},
#  {'head': 'Protein Data Bank', 'tail': 'TBP', 'relation': 'has part'},
#  {'head': 'TBP', 'tail': 'Protein Data Bank', 'relation': 'part of'},
#  {'head': 'P', 'tail': 'P', 'relation': 'has part'},
#  {'head': 'P', 'tail': 'P', 'relation': 'part of'},
#  {'head': '110', 'tail': '110', 'relation': 'point in time'},
#  {'head': 'TBP', 'tail': 'force', 'relation': 'has part'},
#  {'head': 'cell', 'tail': 'cell', 'relation': 'subclass of'},
#  {'head': 'Nucleic A cids R es',
#   'tail': '2006',
#   'relation': 'publication date'},
#  {'head': 'Nucleic A cids R es',
#   'tail': '2003',
#   'relation': 'publication date'},
#  {'head': 'London', 'tail': 'England', 'relation': 'capital of'},
#  {'head': 'England', 'tail': 'London', 'relation': 'capital'},
#  {'head': 'Potsdam', 'tail': 'Germany', 'relation': 'country'},
#  {'head': 'myosin', 'tail': 'actin', 'relation': 'part of'},
#  {'head': 'actin', 'tail': 'myosin', 'relation': 'has part'},
#  {'head': 'ligand', 'tail': 'protein', 'relation': 'part of'},
#  {'head': 'E1', 'tail': 'L', 'relation': 'followed by'},
#  {'head': 'L', 'tail': 'E1', 'relation': 'follows'},
#  {'head': 'DHFR', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'induced-ﬁt', 'tail': 'binding', 'relation': 'subclass of'},
#  {'head': 'myosin', 'tail': 'nucleotide', 'relation': 'has part'},
#  {'head': 'Biochemistry', 'tail': 'biomolecules', 'relation': 'studies'},
#  {'head': 'biomolecules', 'tail': 'Biochemistry', 'relation': 'studied by'},
#  {'head': 'MAP', 'tail': 'map', 'relation': 'instance of'},
#  {'head': 'Elsevier',
#   'tail': 'Amsterdam',
#   'relation': 'location of formation'},
#  {'head': 'viral', 'tail': 'capsid', 'relation': 'has part'},
#  {'head': 'capsid', 'tail': 'viral', 'relation': 'part of'},
#  {'head': 'Lennar d-Jonespotential',
#   'tail': 'potential',
#   'relation': 'subclass of'},
#  {'head': 'nucleation', 'tail': 'capsid', 'relation': 'has effect'},
#  {'head': 'capsid', 'tail': 'nucleation', 'relation': 'has cause'},
#  {'head': '0 0', 'tail': '0', 'relation': 'length'},
#  {'head': '1 0', 'tail': '0', 'relation': 'length'},
#  {'head': '2', 'tail': '0', 'relation': 'length'},
#  {'head': 'biological', 'tail': 'biological', 'relation': 'has part'},
#  {'head': 'biological', 'tail': 'biological', 'relation': 'part of'},
#  {'head': 'Natl.', 'tail': 'Sci.', 'relation': 'part of'},
#  {'head': 'Sci.', 'tail': 'Natl.', 'relation': 'has part'},
#  {'head': 'BioEssays', 'tail': 'Nature', 'relation': 'publisher'},
#  {'head': 'Nicodemi', 'tail': 'Prisco', 'relation': 'student'},
#  {'head': 'Prisco', 'tail': 'Nicodemi', 'relation': 'student of'},
#  {'head': 'molecule', 'tail': 'atom', 'relation': 'has part'},
#  {'head': 'Nregime', 'tail': 'N', 'relation': 'has part'},
#  {'head': 'reverse transcriptase',
#   'tail': 'Proteins',
#   'relation': 'subclass of'},
#  {'head': '1', 'tail': '1', 'relation': 'point in time'},
#  {'head': 'Beijing', 'tail': 'China', 'relation': 'country'},
#  {'head': 'China', 'tail': 'Beijing', 'relation': 'capital'},
#  {'head': 'Equation', 'tail': 'equation', 'relation': 'subclass of'},
#  {'head': 'Biochemistry', 'tail': 'protein', 'relation': 'studies'},
#  {'head': 'protein', 'tail': 'Biochemistry', 'relation': 'studied by'},
#  {'head': '2002', 'tail': '2002', 'relation': 'point in time'},
#  {'head': 'Yale University',
#   'tail': 'New Haven',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'Gilad', 'tail': 'Israel', 'relation': 'country'},
#  {'head': 'conditions', 'tail': 'conditions', 'relation': 'subclass of'},
#  {'head': 'PPII', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'CTPR2', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'tandem', 'tail': 'protein', 'relation': 'subclass of'},
#  {'head': 'CTPR3', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'CTPR4', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'CTPR6', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'CTPR8', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'Amersham Bioscience',
#   'tail': 'Uppsala',
#   'relation': 'headquarters location'},
#  {'head': 'Amersham Bioscience', 'tail': 'Sweden', 'relation': 'country'},
#  {'head': 'Uppsala', 'tail': 'Sweden', 'relation': 'country'},
#  {'head': 'Olympus', 'tail': 'Japan', 'relation': 'country'},
#  {'head': 'Tokyo', 'tail': 'Japan', 'relation': 'country'},
#  {'head': 'Japan',
#   'tail': 'Tokyo',
#   'relation': 'contains administrative territorial entity'},
#  {'head': 'Chung Li', 'tail': 'Taiwan', 'relation': 'country'},
#  {'head': 'Rh', 'tail': 'Rh', 'relation': 'has part'},
#  {'head': 'Rh', 'tail': 'Rh', 'relation': 'part of'},
#  {'head': 'CTPR8', 'tail': 'proteins', 'relation': 'instance of'},
#  {'head': '\uf071', 'tail': '\uf071', 'relation': 'has part'},
#  {'head': 'all', 'tail': 'all', 'relation': 'has part'},
#  {'head': 'all', 'tail': 'all', 'relation': 'part of'},
#  {'head': 'Regan', 'tail': 'Haran Labs', 'relation': 'part of'},
#  {'head': 'Haran Labs', 'tail': 'Regan', 'relation': 'has part'},
#  {'head': 'Biopolymers', 'tail': 'proteins', 'relation': 'subclass of'},
#  {'head': 'D.C.',
#   'tail': 'Washington',
#   'relation': 'twinned administrative body'},
#  {'head': 'Washington',
#   'tail': 'D.C.',
#   'relation': 'twinned administrative body'},
#  {'head': 'PQE-1', 'tail': 'proteins', 'relation': 'instance of'},
#  {'head': 'Talanta', 'tail': '87', 'relation': 'number of episodes'},
#  {'head': 'CTPR2', 'tail': 'proteins', 'relation': 'instance of'},
#  {'head': 'CTPR3', 'tail': 'proteins', 'relation': 'instance of'},
#  {'head': 'CTPR4', 'tail': 'proteins', 'relation': 'instance of'},
#  {'head': 'CTPT6', 'tail': 'proteins', 'relation': 'instance of'},
#  {'head': 'native', 'tail': 'proteins', 'relation': 'subclass of'},
#  {'head': 'unfolded', 'tail': 'proteins', 'relation': 'subclass of'},
#  {'head': 'University of Stuttgart',
#   'tail': 'Stuttgart',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'University of Stuttgart', 'tail': 'Germany', 'relation': 'country'},
#  {'head': 'Stuttgart', 'tail': 'Germany', 'relation': 'country'},
#  {'head': 'Berlin', 'tail': 'Germany', 'relation': 'country'},
#  {'head': 'Germany',
#   'tail': 'Berlin',
#   'relation': 'contains administrative territorial entity'},
#  {'head': 'London',
#   'tail': 'Ontario',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'London', 'tail': 'Canada', 'relation': 'country'},
#  {'head': 'Ontario', 'tail': 'Canada', 'relation': 'country'},
#  {'head': 'Canada',
#   'tail': 'Ontario',
#   'relation': 'contains administrative territorial entity'},
#  {'head': 'ATP', 'tail': 'nucleotide', 'relation': 'subclass of'},
#  {'head': 'ADP', 'tail': 'nucleotide', 'relation': 'subclass of'},
#  {'head': 'phosphate', 'tail': 'nucleotide', 'relation': 'subclass of'},
#  {'head': 'ATP', 'tail': 'nucleotide', 'relation': 'has part'},
#  {'head': 'University of Western Ontario',
#   'tail': 'Canada',
#   'relation': 'country'},
#  {'head': 'EGFP', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'EGFP', 'tail': 'fluorescence', 'relation': 'subclass of'},
#  {'head': 'University of Freiburg', 'tail': 'Germany', 'relation': 'country'},
#  {'head': 'University of Western Ontario',
#   'tail': 'London',
#   'relation': 'headquarters location'},
#  {'head': 'Landesstiftung Baden-Württemberg',
#   'tail': 'Linz',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'Lett', 'tail': 'Lett', 'relation': 'has part'},
#  {'head': 'Lett', 'tail': 'Lett', 'relation': 'part of'},
#  {'head': 'Opt Express',
#   'tail': 'Proc Natl Acad Sci USA',
#   'relation': 'publisher'},
#  {'head': 'Hanoi', 'tail': 'Vietnam', 'relation': 'country'},
#  {'head': 'Vietnam',
#   'tail': 'Hanoi',
#   'relation': 'contains administrative territorial entity'},
#  {'head': 'Lausanne', 'tail': 'Switzerland', 'relation': 'country'},
#  {'head': 'University of Lausanne',
#   'tail': 'Lausanne',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'University of Lausanne',
#   'tail': 'Switzerland',
#   'relation': 'country'},
#  {'head': 'role', 'tail': 'role', 'relation': 'instance of'},
#  {'head': 'INFN', 'tail': 'Vietnam', 'relation': 'country'},
#  {'head': 'Cornell University Press',
#   'tail': 'Ithaca',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'Proteins',
#   'tail': 'Proc Natl Acad Sci USA',
#   'relation': 'publisher'},
#  {'head': 'Krau',
#   'tail': 'Krau',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'Oschkinat H',
#   'tail': 'Proc Natl Acad Sci USA',
#   'relation': 'member of'},
#  {'head': 'Fersht AR',
#   'tail': 'Proc Natl Acad Sci USA',
#   'relation': 'member of'},
#  {'head': 'University of Pittsburgh',
#   'tail': 'Pittsburgh',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'AIS', 'tail': 'Perl', 'relation': 'programming language'},
#  {'head': 'na', 'tail': 'na', 'relation': 'has part'},
#  {'head': 'NMR', 'tail': 'structure', 'relation': 'studies'},
#  {'head': 'structure', 'tail': 'NMR', 'relation': 'studied by'},
#  {'head': 'NSF', 'tail': 'NIH', 'relation': 'subsidiary'},
#  {'head': 'NIH', 'tail': 'NSF', 'relation': 'part of'},
#  {'head': 'TheXplor-NIHNMRmolecularstructuredeterminationpacka',
#   'tail': '1998',
#   'relation': 'publication date'},
#  {'head': 'DYANA', 'tail': '1997', 'relation': 'inception'},
#  {'head': 'Alan M. Ferrenberg',
#   'tail': 'Robert H. Swendsen',
#   'relation': 'student'},
#  {'head': 'Robert H. Swendsen',
#   'tail': 'Alan M. Ferrenberg',
#   'relation': 'student of'},
#  {'head': 'Warsaw', 'tail': 'Taiwan', 'relation': 'country'},
#  {'head': 'Academia Sinica',
#   'tail': 'Nankang',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'Academia Sinica', 'tail': 'Taiwan', 'relation': 'country'},
#  {'head': 'Nankang',
#   'tail': 'Taipei',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'Nankang', 'tail': 'Taiwan', 'relation': 'country'},
#  {'head': 'Taipei',
#   'tail': 'Nankang',
#   'relation': 'contains administrative territorial entity'},
#  {'head': 'Taipei', 'tail': 'Taiwan', 'relation': 'country'},
#  {'head': 'Chung Yuan Christian University',
#   'tail': 'Taiwan',
#   'relation': 'country'},
#  {'head': 'Taiwan',
#   'tail': 'Taipei',
#   'relation': 'contains administrative territorial entity'},
#  {'head': 'ubiquitin', 'tail': 'ubiquitin', 'relation': 'instance of'},
#  {'head': 'domain', 'tail': 'protein', 'relation': 'part of'},
#  {'head': 'ubiquitin', 'tail': 'Lys48', 'relation': 'has part'},
#  {'head': 'Ub', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'Ub', 'tail': 'ubiquitin', 'relation': 'part of'},
#  {'head': 'Ub', 'tail': 'Ub', 'relation': 'has part'},
#  {'head': 'Ub', 'tail': 'Ub', 'relation': 'part of'},
#  {'head': 'Lennard-Jones potential',
#   'tail': 'potential',
#   'relation': 'instance of'},
#  {'head': 'S4', 'tail': 'S2', 'relation': 'followed by'},
#  {'head': 'S2', 'tail': 'S4', 'relation': 'follows'},
#  {'head': 'S2', 'tail': 'S3', 'relation': 'followed by'},
#  {'head': 'S3', 'tail': 'S2', 'relation': 'follows'},
#  {'head': 'S3', 'tail': 'S1', 'relation': 'follows'},
#  {'head': 'S3', 'tail': 'S5', 'relation': 'followed by'},
#  {'head': 'S1', 'tail': 'S3', 'relation': 'followed by'},
#  {'head': 'S5', 'tail': 'S3', 'relation': 'follows'},
#  {'head': 'titin', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'Ub', 'tail': 'protein', 'relation': 'subclass of'},
#  {'head': 'Ub', 'tail': 'Lys48', 'relation': 'has part'},
#  {'head': 'Lys48', 'tail': 'Ub', 'relation': 'part of'},
#  {'head': 'N-C', 'tail': 'O', 'relation': 'has part'},
#  {'head': 'Ub', 'tail': 'proteins', 'relation': 'subclass of'},
#  {'head': 'Jpn', 'tail': 'Natl.', 'relation': 'part of'},
#  {'head': 'Natl.', 'tail': 'Jpn', 'relation': 'has part'},
#  {'head': 'Oxford Science Pub', 'tail': 'UK', 'relation': 'country'},
#  {'head': 'Physica', 'tail': 'journal', 'relation': 'instance of'},
#  {'head': '1997', 'tail': '1997', 'relation': 'point in time'},
#  {'head': 'Ub', 'tail': 'PDB', 'relation': 'part of'},
#  {'head': 'S3', 'tail': 'S5', 'relation': 'connects with'},
#  {'head': 'S5', 'tail': 'S3', 'relation': 'connects with'},
#  {'head': 'Osaka University', 'tail': 'Japan', 'relation': 'country'},
#  {'head': 'Suita',
#   'tail': 'O saka',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'Suita', 'tail': 'Japan', 'relation': 'country'},
#  {'head': 'O saka',
#   'tail': 'Suita',
#   'relation': 'contains administrative territorial entity'},
#  {'head': 'O saka', 'tail': 'Japan', 'relation': 'country'},
#  {'head': 'Japan',
#   'tail': 'O saka',
#   'relation': 'contains administrative territorial entity'},
#  {'head': 'Amino', 'tail': 'Japan', 'relation': 'country'},
#  {'head': '2.2', 'tail': '2', 'relation': 'point in time'},
#  {'head': 'SNEP660101', 'tail': 'PSSM', 'relation': 'instance of'},
#  {'head': 'PDB', 'tail': 'Pfam', 'relation': 'has part'},
#  {'head': 'Pfam', 'tail': 'PDB', 'relation': 'part of'},
#  {'head': 'CHAM 830106', 'tail': 'proteins', 'relation': 'instance of'},
#  {'head': 'homologs', 'tail': 'protein', 'relation': 'subclass of'},
#  {'head': 'AAindex', 'tail': '2006', 'relation': 'publication date'},
#  {'head': 'Oobatake M', 'tail': 'PSSM', 'relation': 'notable work'},
#  {'head': 'PSSM', 'tail': 'Oobatake M', 'relation': 'discoverer or inventor'},
#  {'head': 'VYWTSPFMKLIHGEQCDNRAr-SV',
#   'tail': 'VYWTSPFMKLIHGEQCDNRAr-SV',
#   'relation': 'contains administrative territorial entity'},
#  {'head': 'VYWTSPFMKLIHGEQCDNRAr-SV',
#   'tail': 'VYWTSPFMKLIHGEQCDNRAr-SV',
#   'relation': 'shares border with'},
#  {'head': 'NH', 'tail': 'alpha', 'relation': 'has part'},
#  {'head': 'Kyoto University',
#   'tail': 'Kyoto',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'Kyoto University', 'tail': 'Japan', 'relation': 'country'},
#  {'head': 'Kyoto', 'tail': 'Japan', 'relation': 'country'},
#  {'head': 'Osaka University',
#   'tail': 'Toyonaka',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'Japan Science and Technology Agency',
#   'tail': 'Japan',
#   'relation': 'country'},
#  {'head': 'Osaka', 'tail': 'Japan', 'relation': 'country'},
#  {'head': 'Osaka University',
#   'tail': 'Osaka',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'Toyonaka',
#   'tail': 'Osaka',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'Osaka',
#   'tail': 'Toyonaka',
#   'relation': 'contains administrative territorial entity'},
#  {'head': 'KIF1A', 'tail': 'MT', 'relation': 'part of'},
#  {'head': 'MT', 'tail': 'KIF1A', 'relation': 'has part'},
#  {'head': 'KIF1A', 'tail': 'kinesin', 'relation': 'subclass of'},
#  {'head': 'nucleotide', 'tail': 'nucle otide', 'relation': 'part of'},
#  {'head': 'PDB', 'tail': 'D', 'relation': 'has part'},
#  {'head': 'D', 'tail': 'PDB', 'relation': 'part of'},
#  {'head': 'L11', 'tail': 'loop', 'relation': 'instance of'},
#  {'head': 'L12', 'tail': 'loop', 'relation': 'instance of'},
#  {'head': '270', 'tail': '290', 'relation': 'followed by'},
#  {'head': '290', 'tail': '270', 'relation': 'follows'},
#  {'head': 'KIF1A', 'tail': 'nucleotide', 'relation': 'subclass of'},
#  {'head': 'KIF1A', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'nucleotide', 'tail': 'protein', 'relation': 'part of'},
#  {'head': 'nucleotide', 'tail': 'molecule', 'relation': 'part of'},
#  {'head': 'molecule', 'tail': 'nucleotide', 'relation': 'has part'},
#  {'head': 'C α', 'tail': 'protein', 'relation': 'part of'},
#  {'head': 'KIF1A',
#   'tail': 'Accordingtonucleotidestates',
#   'relation': 'instance of'},
#  {'head': 'Proteins', 'tail': 'Natl.', 'relation': 'part of'},
#  {'head': 'Natl.', 'tail': 'Proteins', 'relation': 'has part'},
#  {'head': 'N.', 'tail': 'Natl.', 'relation': 'part of'},
#  {'head': '14', 'tail': '23', 'relation': 'part of'},
#  {'head': '23', 'tail': '14', 'relation': 'has part'},
#  {'head': 'University of Cologne', 'tail': 'Germany', 'relation': 'country'},
#  {'head': 'RNA', 'tail': 'protein', 'relation': 'subclass of'},
#  {'head': 'Brownian dynamics',
#   'tail': 'Fokker-Planck equation',
#   'relation': 'has part'},
#  {'head': 'Fokker-Planck equation',
#   'tail': 'Brownian dynamics',
#   'relation': 'part of'},
#  {'head': 'Toyonaka', 'tail': 'Japan', 'relation': 'country'},
#  {'head': 'Japan Science and Technology Agency',
#   'tail': 'Nagoya',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'Nagoya', 'tail': 'Japan', 'relation': 'country'},
#  {'head': 'Japan Science and Technology Agency',
#   'tail': 'Suita',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'Nagoya University',
#   'tail': 'Nagoya',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'Nagoya University', 'tail': 'Japan', 'relation': 'country'},
#  {'head': 'kinesin', 'tail': 'protein', 'relation': 'subclass of'},
#  {'head': 'microtubule', 'tail': 'microtubule', 'relation': 'part of'},
#  {'head': 'microtubule', 'tail': 'microtubule', 'relation': 'has part'},
#  {'head': 'two', 'tail': 'jumps', 'relation': 'subclass of'},
#  {'head': 'minima', 'tail': 'free-energy landsca pe', 'relation': 'part of'},
#  {'head': 'free-energy landsca pe', 'tail': 'minima', 'relation': 'has part'},
#  {'head': 'SWII', 'tail': 'kinesin', 'relation': 'part of'},
#  {'head': 'Kinesin', 'tail': 'protein', 'relation': 'subclass of'},
#  {'head': 'kinesin', 'tail': 'proteins', 'relation': 'subclass of'},
#  {'head': 'Onuchic JN',
#   'tail': 'Proc Natl Acad Sci USA',
#   'relation': 'member of'},
#  {'head': 'Socci ND',
#   'tail': 'Proc Natl Acad Sci USA',
#   'relation': 'member of'},
#  {'head': 'Wolynes PG',
#   'tail': 'Proc Natl Acad Sci USA',
#   'relation': 'member of'},
#  {'head': 'Fossati', 'tail': 'Fossati', 'relation': 'named after'},
#  {'head': 'Sablin EP',
#   'tail': 'Proc Natl Acad Sci USA',
#   'relation': 'member of'},
#  {'head': 'Vale RD',
#   'tail': 'Proc Natl Acad Sci USA',
#   'relation': 'member of'},
#  {'head': 'Kollman PA',
#   'tail': 'Proc Natl Acad Sci USA',
#   'relation': 'member of'},
#  {'head': 'Boston University',
#   'tail': 'Massachusetts',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'Boston University', 'tail': 'USA', 'relation': 'country'},
#  {'head': 'Boston', 'tail': 'USA', 'relation': 'country'},
#  {'head': 'Massachusetts', 'tail': 'USA', 'relation': 'country'},
#  {'head': 'USA',
#   'tail': 'Massachusetts',
#   'relation': 'contains administrative territorial entity'},
#  {'head': 'Bunkyo-ku',
#   'tail': 'Tokyo',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'Tokyo',
#   'tail': 'Bunkyo-ku',
#   'relation': 'contains administrative territorial entity'},
#  {'head': 'normal mode analysis',
#   'tail': 'molecular dynamics',
#   'relation': 'subclass of'},
#  {'head': 'Corcelli',
#   'tail': 'Corcelli',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'La Sapienza University of Rome',
#   'tail': 'Rome',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'La Sapienza University of Rome',
#   'tail': 'Italy',
#   'relation': 'country'},
#  {'head': 'Rome', 'tail': 'Italy', 'relation': 'country'},
#  {'head': 'Italy', 'tail': 'Rome', 'relation': 'capital'},
#  {'head': 'DISOPRED2', 'tail': 'proteins', 'relation': 'instance of'},
#  {'head': 'pr oteins', 'tail': 'proteins', 'relation': 'subclass of'},
#  {'head': 'gVSL2', 'tail': 'VSL2', 'relation': 'based on'},
#  {'head': 'proteins', 'tail': 'proteins', 'relation': 'subclass of'},
#  {'head': 'eukaryotic', 'tail': 'euka ryotic', 'relation': 'has part'},
#  {'head': 'base', 'tail': 'base', 'relation': 'part of'},
#  {'head': 'base', 'tail': 'base', 'relation': 'has part'},
#  {'head': 'Eukarya', 'tail': 'cell', 'relation': 'subclass of'},
#  {'head': 'proteins', 'tail': 'sequence', 'relation': 'has part'},
#  {'head': 'sequence', 'tail': 'proteins', 'relation': 'part of'},
#  {'head': 'FoldIndex', 'tail': 'FoldIndex', 'relation': 'has part'},
#  {'head': 'FoldIndex', 'tail': 'FoldIndex', 'relation': 'part of'},
#  {'head': 'IEEE International Conference on Neural Network',
#   'tail': '1997',
#   'relation': 'point in time'},
#  {'head': 'Uversky VN', 'tail': 'Gillespie JR', 'relation': 'has part'},
#  {'head': 'Gillespie JR', 'tail': 'Uversky VN', 'relation': 'part of'},
#  {'head': 'Obradovic Z',
#   'tail': 'Bioinformatics',
#   'relation': 'field of work'},
#  {'head': 'DisProt', 'tail': 'Bioinformatics', 'relation': 'field of work'},
#  {'head': '2007', 'tail': '2007', 'relation': 'point in time'},
#  {'head': '24.4', 'tail': '16.2', 'relation': 'said to be the same as'},
#  {'head': '16.2', 'tail': '24.4', 'relation': 'said to be the same as'},
#  {'head': 'DISOPRED2', 'tail': 'proteins', 'relation': 'facet of'},
#  {'head': 'Bacteria', 'tail': 'Eukarya', 'relation': 'parent taxon'},
#  {'head': 'November', 'tail': 'November', 'relation': 'point in time'},
#  {'head': '3-noncrossing', 'tail': '3', 'relation': 'event distance'},
#  {'head': 'A112', 'tail': 'nucleotide', 'relation': 'subclass of'},
#  {'head': 'φ', 'tail': 'Randφ', 'relation': 'has part'},
#  {'head': 'Theorem 3', 'tail': 'Theorem 4', 'relation': 'followed by'},
#  {'head': 'Lemma 1', 'tail': 'Theorem 1', 'relation': 'part of'},
#  {'head': 'Lemma 3', 'tail': 'Theorem 1', 'relation': 'part of'},
#  {'head': 'Theorem 1', 'tail': 'Lemma 1', 'relation': 'has part'},
#  {'head': 'Theorem 1', 'tail': 'Lemma 3', 'relation': 'has part'},
#  {'head': 'tk', 'tail': 'tk', 'relation': 'has part'},
#  {'head': 'Nankai University', 'tail': 'China', 'relation': 'country'},
#  {'head': 'Paris', 'tail': 'France', 'relation': 'country'},
#  {'head': 'mechanical', 'tail': 'geometrical', 'relation': 'studied by'},
#  {'head': 'geometrical', 'tail': 'mechanical', 'relation': 'studies'},
#  {'head': 'RNA polymerase', 'tail': 'enzymes', 'relation': 'subclass of'},
#  {'head': 'angle', 'tail': 'geometrical', 'relation': 'studied by'},
#  {'head': 'LPS',
#   'tail': 'Paris',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'ENS',
#   'tail': 'Paris',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'ang le', 'tail': 'experim ental data', 'relation': 'subclass of'},
#  {'head': 'Physical Review Letters',
#   'tail': 'USA',
#   'relation': 'country of origin'},
#  {'head': 'Biophysical Journal',
#   'tail': '73',
#   'relation': 'number of articles'},
#  {'head': 'Cam bridge',
#   'tail': 'England',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'ion', 'tail': 'atom', 'relation': 'part of'},
#  {'head': '9ILB', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': '1KX8', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': '1MB1', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': '1RN7', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': '9ILB', 'tail': '1KX8', 'relation': 'followed by'},
#  {'head': '1KX8', 'tail': '9ILB', 'relation': 'follows'},
#  {'head': '1MB1', 'tail': 'CNS', 'relation': 'part of'},
#  {'head': 'CNS', 'tail': '1MB1', 'relation': 'has part'},
#  {'head': '0', 'tail': '0', 'relation': 'has part'},
#  {'head': '1MB1', 'tail': '1BYW', 'relation': 'followed by'},
#  {'head': '1BYW', 'tail': '1MB1', 'relation': 'follows'},
#  {'head': 'Pro-80', 'tail': 'lo op', 'relation': 'instance of'},
#  {'head': 'Leu-82', 'tail': 'lo op', 'relation': 'instance of'},
#  {'head': 'Asp-83', 'tail': 'lo op', 'relation': 'instance of'},
#  {'head': 'Asn-84', 'tail': 'lo op', 'relation': 'instance of'},
#  {'head': '1', 'tail': '2', 'relation': 'followed by'},
#  {'head': '2', 'tail': '3', 'relation': 'followed by'},
#  {'head': '3', 'tail': '2', 'relation': 'follows'},
#  {'head': '1MB1', 'tail': '2', 'relation': 'length'},
#  {'head': '1RN7', 'tail': '1BYW', 'relation': 'part of'},
#  {'head': '1BYW', 'tail': '1RN7', 'relation': 'has part'},
#  {'head': '0.3', 'tail': '0.3', 'relation': 'point in time'},
#  {'head': '1BYW', 'tail': '2DBO', 'relation': 'followed by'},
#  {'head': '2DBO', 'tail': '1BYW', 'relation': 'follows'},
#  {'head': 'Lys-86', 'tail': 'Lys-87', 'relation': 'followed by'},
#  {'head': 'Lys-87', 'tail': 'Lys-86', 'relation': 'follows'},
#  {'head': '7:13', 'tail': '7', 'relation': 'number of episodes'},
#  {'head': 'GroEL', 'tail': 'chaperonin', 'relation': 'subclass of'},
#  {'head': 'chaperonin', 'tail': 'protein', 'relation': 'subclass of'},
#  {'head': 'protein', 'tail': 'chaperonin', 'relation': 'has part'},
#  {'head': 'chaperonin', 'tail': 'protein', 'relation': 'part of'},
#  {'head': 'Fig. 2', 'tail': '2', 'relation': 'depicts'},
#  {'head': 'GroEL', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'Science', 'tail': 'Biochem', 'relation': 'has part'},
#  {'head': 'Biochem', 'tail': 'Science', 'relation': 'part of'},
#  {'head': 'Nature', 'tail': 'Natl.', 'relation': 'part of'},
#  {'head': 'Natl.', 'tail': 'Nature', 'relation': 'has part'},
#  {'head': 'Z', 'tail': 'Z', 'relation': 'said to be the same as'},
#  {'head': 'J. Mol.', 'tail': 'Natl.', 'relation': 'part of'},
#  {'head': 'Natl.', 'tail': 'J. Mol.', 'relation': 'has part'},
#  {'head': 'Di Nardo', 'tail': 'J. R.', 'relation': 'member of'},
#  {'head': 'Tipton', 'tail': 'J. R.', 'relation': 'member of'},
#  {'head': 'J. R.', 'tail': 'Di Nardo', 'relation': 'has part'},
#  {'head': 'J. R.', 'tail': 'Tipton', 'relation': 'has part'},
#  {'head': 'Muenster', 'tail': 'Germany', 'relation': 'country'},
#  {'head': 'complex', 'tail': 'complex', 'relation': 'subclass of'},
#  {'head': 'Annual Review of Genetics',
#   'tail': 'Axelrod F',
#   'relation': 'author'},
#  {'head': 'Journal of Molecular Recognition',
#   'tail': '2002',
#   'relation': 'publication date'},
#  {'head': 'two', 'tail': 'two', 'relation': 'number of episodes'},
#  {'head': '45', 'tail': '45', 'relation': 'number of episodes'},
#  {'head': '1469', 'tail': '1469', 'relation': 'point in time'},
#  {'head': 'C α', 'tail': 'N', 'relation': 'has part'},
#  {'head': 'N', 'tail': 'C α', 'relation': 'part of'},
#  {'head': 'Polish Academy of Sciences',
#   'tail': 'Warsaw',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'integrin', 'tail': 'proteins', 'relation': 'subclass of'},
#  {'head': 'ubiquitin', 'tail': 'proteins', 'relation': 'instance of'},
#  {'head': 'ubiquitin', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'integrin', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'Lennard- Jones potential',
#   'tail': 'potential',
#   'relation': 'instance of'},
#  {'head': 'de la Torre', 'tail': 'Antosiewicz', 'relation': 'student'},
#  {'head': 'Antosiewicz', 'tail': 'de la Torre', 'relation': 'student of'},
#  {'head': 'Ubiquitin', 'tail': 'integrin', 'relation': 'different from'},
#  {'head': 'integrin', 'tail': 'Ubiquitin', 'relation': 'different from'},
#  {'head': 'Fig. 4', 'tail': '4', 'relation': 'length'},
#  {'head': 'integrin', 'tail': 'Cterminus', 'relation': 'has part'},
#  {'head': 'Cterminus', 'tail': 'integrin', 'relation': 'part of'},
#  {'head': 'Jan Antosiewicz',
#   'tail': 'Warsaw University of Technology',
#   'relation': 'employer'},
#  {'head': 'China',
#   'tail': 'Hong Kong',
#   'relation': 'contains administrative territorial entity'},
#  {'head': 'Hong Kong',
#   'tail': 'China',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'Physical Review Letters',
#   'tail': 'journal',
#   'relation': 'instance of'},
#  {'head': 'Biophysical Journal',
#   'tail': 'Physical Review Letters',
#   'relation': 'publisher'},
#  {'head': '1970', 'tail': '1970', 'relation': 'point in time'},
#  {'head': 'Journal of Biomolecular NMR',
#   'tail': '14',
#   'relation': 'number of articles'},
#  {'head': 'Biophysical Journal',
#   'tail': '78',
#   'relation': 'number of articles'},
#  {'head': 'C terminus', 'tail': 'helix', 'relation': 'part of'},
#  {'head': 'Celoria',
#   'tail': 'Milan',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'Celoria', 'tail': 'Italy', 'relation': 'country'},
#  {'head': 'Milan',
#   'tail': 'Celoria',
#   'relation': 'contains administrative territorial entity'},
#  {'head': 'Milan', 'tail': 'Italy', 'relation': 'country'},
#  {'head': 'protein', 'tail': 'domain', 'relation': 'has part'},
#  {'head': 'G', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'GROMACS', 'tail': 'mole cular dynamics', 'relation': 'use'},
#  {'head': '21', 'tail': '21', 'relation': 'point in time'},
#  {'head': 'helix', 'tail': 'protein', 'relation': 'part of'},
#  {'head': 'protein', 'tail': 'helix', 'relation': 'has part'},
#  {'head': 'Loops', 'tail': 'loop', 'relation': 'subclass of'},
#  {'head': 'Orban', 'tail': 'Orban', 'relation': 'family'},
#  {'head': 'Critical', 'tail': 'Critical', 'relation': 'instance of'},
#  {'head': 'The Missing Term in Eﬀective Pair Potentials',
#   'tail': 'Hess B',
#   'relation': 'author'},
#  {'head': 'The Missing Term in Eﬀective Pair Potentials',
#   'tail': 'Berendsen HJC',
#   'relation': 'author'},
#  {'head': 'structure', 'tail': 'structure', 'relation': 'part of'},
#  {'head': 'Kbis', 'tail': 'force', 'relation': 'instance of'},
#  {'head': '¯ nr', 'tail': '¯ nr', 'relation': 'different from'},
#  {'head': 'Flanders',
#   'tail': 'England',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'England',
#   'tail': 'Flanders',
#   'relation': 'contains administrative territorial entity'},
#  {'head': 'GB1', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'diversity', 'tail': 'diversity', 'relation': 'facet of'},
#  {'head': 'Nucleic Acids Res',
#   'tail': 'Proc Natl Acad Sci',
#   'relation': 'publisher'},
#  {'head': 'Kasper Peeters',
#   'tail': 'Utrecht University',
#   'relation': 'educated at'},
#  {'head': 'Viral tiling',
#   'tail': 'viral t iling theory',
#   'relation': 'facet of'},
#  {'head': 'pr otein', 'tail': 'viral tiling', 'relation': 'part of'},
#  {'head': 'viral tiling', 'tail': 'pr otein', 'relation': 'has part'},
#  {'head': 'Wigner', 'tail': 'chemistry', 'relation': 'field of work'},
#  {'head': 'chemical', 'tail': 'molecule', 'relation': 'studies'},
#  {'head': 'molecule', 'tail': 'chemical', 'relation': 'studied by'},
#  {'head': 'TBSV', 'tail': 'VIPERdb', 'relation': 'part of'},
#  {'head': 'VIPERdb', 'tail': 'TBSV', 'relation': 'has part'},
#  {'head': '3.1', 'tail': '3', 'relation': 'point in time'},
#  {'head': 'RYMV', 'tail': 'capsid', 'relation': 'instance of'},
#  {'head': 'HK 97', 'tail': 'c apsid', 'relation': 'instance of'},
#  {'head': 'capsid', 'tail': 'STMV', 'relation': 'part of'},
#  {'head': 'STMV', 'tail': 'capsid', 'relation': 'has part'},
#  {'head': 'RYMV', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'CCMV', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'Polio', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'Normal Mode Analys',
#   'tail': 'molecular dynamics',
#   'relation': 'use'},
#  {'head': 'VIPERdb', 'tail': 'capsid', 'relation': 'facet of'},
#  {'head': 'twelve', 'tail': 'twelve', 'relation': 'number of episodes'},
#  {'head': 'VIPERdb', 'tail': 'viral capsids', 'relation': 'facet of'},
#  {'head': 'ammonia', 'tail': 'C3vand', 'relation': 'has part'},
#  {'head': 'C3vand', 'tail': 'ammonia', 'relation': 'part of'},
#  {'head': 'frequency', 'tail': 'frequency', 'relation': 'subclass of'},
#  {'head': 'Visualisation', 'tail': 'Visualisation', 'relation': 'subclass of'},
#  {'head': 'Clarendon Pre ss', 'tail': 'Oxford', 'relation': 'part of'},
#  {'head': '1976', 'tail': '1976', 'relation': 'point in time'},
#  {'head': 'J. Rudnick',
#   'tail': 'Molecular dynamics',
#   'relation': 'field of work'},
#  {'head': 'R. Jernigan', 'tail': 'M. Thorpe', 'relation': 'student'},
#  {'head': 'M. Thorpe', 'tail': 'R. Jernigan', 'relation': 'student of'},
#  {'head': 'Institute of Physics',
#   'tail': 'Warsaw',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'Institute of Physics', 'tail': 'Poland', 'relation': 'country'},
#  {'head': 'Polish Academy of Sciences',
#   'tail': 'Poland',
#   'relation': 'country'},
#  {'head': '1gb1', 'tail': 'protein', 'relation': 'subclass of'},
#  {'head': '1l2y', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': '2ci2', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': '1/2', 'tail': '5', 'relation': 'said to be the same as'},
#  {'head': '5', 'tail': '1/2', 'relation': 'said to be the same as'},
#  {'head': '6', 'tail': '6', 'relation': 'point in time'},
#  {'head': 'CU', 'tail': 'CT', 'relation': 'shares border with'},
#  {'head': 'CT', 'tail': 'CU', 'relation': 'shares border with'},
#  {'head': 'CS', 'tail': 'CT', 'relation': 'shares border with'},
#  {'head': 'CS', 'tail': 'CP', 'relation': 'shares border with'},
#  {'head': 'CT', 'tail': 'CS', 'relation': 'shares border with'},
#  {'head': 'CT', 'tail': 'CP', 'relation': 'shares border with'},
#  {'head': 'CP', 'tail': 'CS', 'relation': 'shares border with'},
#  {'head': 'CP', 'tail': 'CT', 'relation': 'shares border with'},
#  {'head': 'CP', 'tail': 'D0', 'relation': 'shares border with'},
#  {'head': 'D0', 'tail': 'CP', 'relation': 'shares border with'},
#  {'head': 'CP', 'tail': 'CQ', 'relation': 'has part'},
#  {'head': 'CQ', 'tail': 'CP', 'relation': 'part of'},
#  {'head': 'D3', 'tail': 'D', 'relation': 'part of'},
#  {'head': 'CU', 'tail': 'D3', 'relation': 'has part'},
#  {'head': 'CP', 'tail': 'CP', 'relation': 'owned by'},
#  {'head': 'CT', 'tail': 'CT', 'relation': 'part of'},
#  {'head': 'CT', 'tail': 'CT', 'relation': 'part'},
#  {'head': 'CQ', 'tail': 'CQ', 'relation': 'has part'},
#  {'head': 'CQ', 'tail': 'CQ', 'relation': 'part of'},
#  {'head': 'CQ', 'tail': 'CS', 'relation': 'part of'},
#  {'head': 'CS', 'tail': 'CQ', 'relation': 'has part'},
#  {'head': 'CQ',
#   'tail': 'CT',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'CS', 'tail': 'DD', 'relation': 'part of'},
#  {'head': 'D3', 'tail': 'DD', 'relation': 'part of'},
#  {'head': 'CV', 'tail': 'DD', 'relation': 'part of'},
#  {'head': 'CT', 'tail': 'DD', 'relation': 'part of'},
#  {'head': 'CQ', 'tail': 'CS', 'relation': 'shares border with'},
#  {'head': 'CS', 'tail': 'CQ', 'relation': 'shares border with'},
#  {'head': 'CQ', 'tail': 'CT', 'relation': 'shares border with'},
#  {'head': 'CT', 'tail': 'CQ', 'relation': 'shares border with'},
#  {'head': 'CT', 'tail': 'B9', 'relation': 'has part'},
#  {'head': 'CT', 'tail': 'C0', 'relation': 'has part'},
#  {'head': 'B9', 'tail': 'CT', 'relation': 'part of'},
#  {'head': 'B9', 'tail': 'C0', 'relation': 'has part'},
#  {'head': 'C0', 'tail': 'B9', 'relation': 'part of'},
#  {'head': 'D3', 'tail': 'CT', 'relation': 'shares border with'},
#  {'head': 'DB', 'tail': 'CT', 'relation': 'shares border with'},
#  {'head': 'CT', 'tail': 'D3', 'relation': 'shares border with'},
#  {'head': 'CT', 'tail': 'DB', 'relation': 'shares border with'},
#  {'head': 'B8', 'tail': 'B8', 'relation': 'has part'},
#  {'head': 'B8', 'tail': 'B8', 'relation': 'part of'},
#  {'head': 'CT', 'tail': 'BA', 'relation': 'shares border with'},
#  {'head': 'CT', 'tail': 'C1', 'relation': 'shares border with'},
#  {'head': 'BA', 'tail': 'CT', 'relation': 'shares border with'},
#  {'head': 'BA', 'tail': 'C1', 'relation': 'shares border with'},
#  {'head': 'C1', 'tail': 'CT', 'relation': 'shares border with'},
#  {'head': 'C1', 'tail': 'BA', 'relation': 'shares border with'},
#  {'head': 'C1', 'tail': 'C1', 'relation': 'part of'},
#  {'head': 'CS', 'tail': 'CT', 'relation': 'has part'},
#  {'head': 'D3', 'tail': 'D3', 'relation': 'part of'},
#  {'head': 'B9',
#   'tail': 'CT',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'BK', 'tail': 'B8', 'relation': 'instance of'},
#  {'head': 'BG', 'tail': 'B8', 'relation': 'instance of'},
#  {'head': 'B8', 'tail': 'BK', 'relation': 'has part'},
#  {'head': 'B8', 'tail': 'BG', 'relation': 'has part'},
#  {'head': 'B8',
#   'tail': 'B8',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'B8', 'tail': 'B8', 'relation': 'located'},
#  {'head': 'B8', 'tail': 'B8', 'relation': 'has'},
#  {'head': 'CS', 'tail': 'D0', 'relation': 'has part'},
#  {'head': 'CT', 'tail': 'CS', 'relation': 'part of'},
#  {'head': 'D0', 'tail': 'CS', 'relation': 'part of'},
#  {'head': '20001201012', 'tail': '20001020', 'relation': 'followed by'},
#  {'head': '20001020', 'tail': '20001201012', 'relation': 'follows'},
#  {'head': '2000101-1012', 'tail': '20001020', 'relation': 'follows'},
#  {'head': '20001020', 'tail': '2000101-1012', 'relation': 'followed by'},
#  {'head': 'D0', 'tail': 'CT', 'relation': 'has part'},
#  {'head': 'D0', 'tail': 'CU', 'relation': 'has part'},
#  {'head': 'D0', 'tail': 'B5', 'relation': 'has part'},
#  {'head': 'CT', 'tail': 'D0', 'relation': 'part of'},
#  {'head': 'CU', 'tail': 'D0', 'relation': 'part of'},
#  {'head': 'CS', 'tail': 'B5', 'relation': 'part of'},
#  {'head': '50', 'tail': '50', 'relation': 'event distance'},
#  {'head': '0.10', 'tail': '0.10', 'relation': 'point in time'},
#  {'head': 'DB', 'tail': 'BH', 'relation': 'shares border with'},
#  {'head': 'Chemistry', 'tail': 'Biochemistry', 'relation': 'has part'},
#  {'head': 'Biochemistry', 'tail': 'Chemistry', 'relation': 'part of'},
#  {'head': 'pyrimidine', 'tail': 'nucleotide', 'relation': 'subclass of'},
#  {'head': 'nucleotide', 'tail': 'nucleotide', 'relation': 'part of'},
#  {'head': 'nucleotide', 'tail': 'nucleotide', 'relation': 'has part'},
#  {'head': 'nucleotide', 'tail': 'bases', 'relation': 'has part'},
#  {'head': 'Hartmann', 'tail': 'NMR', 'relation': 'field of work'},
#  {'head': 'S6', 'tail': 'S6', 'relation': 'part of'},
#  {'head': 'S6', 'tail': 'S6', 'relation': 'has part'},
#  {'head': 'key', 'tail': 'key', 'relation': 'instance of'},
#  {'head': 'Center for Theoretical Bi ological Physics',
#   'tail': 'NSF',
#   'relation': 'parent organization'},
#  {'head': 'kappaB', 'tail': 'oncogene', 'relation': 'subclass of'},
#  {'head': 'J.P.', 'tail': 'J.R.', 'relation': 'different from'},
#  {'head': 'J.R.', 'tail': 'J.P.', 'relation': 'different from'},
#  {'head': 'Numerical-Integration of Cartesian Equations of Motion of a System with Constraints - Molecular-Dynamics of N-Alkanes',
#   'tail': 'Journal of Chemical Physics',
#   'relation': 'published in'},
#  {'head': 'Utrecht University',
#   'tail': 'Th e Netherlands',
#   'relation': 'country'},
#  {'head': 'Durham University',
#   'tail': 'U nited Kingdom',
#   'relation': 'country'},
#  {'head': 'Elastic Network', 'tail': 'RTB', 'relation': 'has part'},
#  {'head': 'RTB', 'tail': 'Elastic Network', 'relation': 'part of'},
#  {'head': 'capsid', 'tail': 'capsid', 'relation': 'part of'},
#  {'head': 'capsid', 'tail': 'capsid', 'relation': 'has part'},
#  {'head': 'University of Niš',
#   'tail': 'Belgrade',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'University of Niš', 'tail': 'Serbia', 'relation': 'country'},
#  {'head': 'Belgrade', 'tail': 'Serbia', 'relation': 'country'},
#  {'head': 'CIPS6', 'tail': 'Tabl e 5', 'relation': 'has part'},
#  {'head': 'Tabl e 5', 'tail': 'CIPS6', 'relation': 'part of'},
#  {'head': 'G.', 'tail': 'G.', 'relation': 'has part'},
#  {'head': 'G.', 'tail': 'G.', 'relation': 'part of'},
#  {'head': 'Nauka',
#   'tail': 'Moscow',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'Moscow',
#   'tail': 'Nauka',
#   'relation': 'contains administrative territorial entity'},
#  {'head': 'Universidad Nacional de Mar del Plata',
#   'tail': 'Mar del Plata',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'Universidad Nacional de Mar del Plata',
#   'tail': 'Argentina',
#   'relation': 'country'},
#  {'head': 'Mar del Plata', 'tail': 'Argentina', 'relation': 'country'},
#  {'head': 'nucleotide', 'tail': 'RNA', 'relation': 'part of'},
#  {'head': '16', 'tail': '17', 'relation': 'followed by'},
#  {'head': '17', 'tail': '16', 'relation': 'follows'},
#  {'head': 'bases', 'tail': 'RNA', 'relation': 'part of'},
#  {'head': 'RNA', 'tail': 'bases', 'relation': 'has part'},
#  {'head': 'one', 'tail': 'one', 'relation': 'instance of'},
#  {'head': 'RNA', 'tail': 'molecule', 'relation': 'subclass of'},
#  {'head': 'Butterworth-Heinemann', 'tail': 'UK', 'relation': 'country'},
#  {'head': 'TnC', 'tail': 'TnI', 'relation': 'has part'},
#  {'head': 'TnI', 'tail': 'TnC', 'relation': 'part of'},
#  {'head': 'change', 'tail': 'change', 'relation': 'facet of'},
#  {'head': 'Rapid', 'tail': 'rapid', 'relation': 'subclass of'},
#  {'head': 'TnC', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'TnI', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'TnC', 'tail': 'complex', 'relation': 'instance of'},
#  {'head': 'TnI', 'tail': 'complex', 'relation': 'instance of'},
#  {'head': 'TnI', 'tail': 'TnC', 'relation': 'has part'},
#  {'head': 'TnI', 'tail': 'TnI', 'relation': 'part of'},
#  {'head': '1n00', 'tail': '1', 'relation': 'point in time'},
#  {'head': 'Structure', 'tail': 'structure', 'relation': 'facet of'},
#  {'head': 'TnC', 'tail': 'TnI', 'relation': 'part of'},
#  {'head': 'protein', 'tail': 'ligand', 'relation': 'has part'},
#  {'head': 'enthalpy', 'tail': 'enthalpy', 'relation': 'part of'},
#  {'head': 'HL052508', 'tail': 'NIH', 'relation': 'parent organization'},
#  {'head': 'HL80186', 'tail': 'NIH', 'relation': 'parent organization'},
#  {'head': 'Biochemistry', 'tail': 'proteins', 'relation': 'studies'},
#  {'head': 'proteins', 'tail': 'Biochemistry', 'relation': 'studied by'},
#  {'head': '2008', 'tail': '2008', 'relation': 'point in time'},
#  {'head': '3', 'tail': '2.6', 'relation': 'said to be the same as'},
#  {'head': '2.6', 'tail': '3', 'relation': 'said to be the same as'},
#  {'head': '0.5', 'tail': '0.51', 'relation': 'said to be the same as'},
#  {'head': '0.51', 'tail': '0.5', 'relation': 'said to be the same as'},
#  {'head': 'dihydrodiol', 'tail': 'NADH', 'relation': 'has part'},
#  {'head': 'Jacomex', 'tail': 'France', 'relation': 'country'},
#  {'head': 'Illkirch', 'tail': 'France', 'relation': 'country'},
#  {'head': 'PAH',
#   'tail': 'PAH',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': '22', 'tail': '22', 'relation': 'point in time'},
#  {'head': 'HP8452', 'tail': 'Les Ulis', 'relation': 'manufacturer'},
#  {'head': 'Supelco', 'tail': 'Sigma-9 Aldrich', 'relation': 'subsidiary'},
#  {'head': 'Sigma-9 Aldrich',
#   'tail': 'Supelco',
#   'relation': 'parent organization'},
#  {'head': 'Cayman Chemical', 'tail': 'France', 'relation': 'country'},
#  {'head': 'Sigma-Aldrich', 'tail': 'France', 'relation': 'country'},
#  {'head': 'Quentin-Fallavier', 'tail': 'France', 'relation': 'country'},
#  {'head': 'oxygen', 'tail': 'oxygen', 'relation': 'has part'},
# ...
#  {'head': 'Journal of Chemical Physics',
#   'tail': '1975',
#   'relation': 'publication date'},
#  {'head': '1974', 'tail': '1974', 'relation': 'point in time'},
#  {'head': 'Journal of Chemical Physics',
#   'tail': '1982',
#   'relation': 'publication date'},
#  {'head': 'Yale University Press',
#   'tail': 'New Haven',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'Journal of Molecular Biology',
#   'tail': '1977',
#   'relation': 'inception'},
#  {'head': 'Ludwig-Maximilians-Universit¨',
#   'tail': 'Germany',
#   'relation': 'country'},
#  {'head': 'bending', 'tail': 'physics', 'relation': 'part of'},
#  {'head': 'Mechanics of Materials',
#   'tail': '1990',
#   'relation': 'publication date'},
#  {'head': 'Hubei', 'tail': 'China', 'relation': 'country'},
#  {'head': 'China',
#   'tail': 'Hubei',
#   'relation': 'contains administrative territorial entity'},
#  {'head': '3-10', 'tail': '10', 'relation': 'said to be the same as'},
#  {'head': '10', 'tail': '3-10', 'relation': 'said to be the same as'},
#  {'head': 'USA', 'tail': 'Natl.', 'relation': 'part of'},
#  {'head': 'Natl.', 'tail': 'USA', 'relation': 'has part'},
#  {'head': 'Oeiras', 'tail': 'Portugal', 'relation': 'country'},
#  {'head': 'Geometry 2', 'tail': 'Geometry 1', 'relation': 'opposite of'},
#  {'head': 'Geometry 1', 'tail': 'Geometry 2', 'relation': 'opposite of'},
#  {'head': 'Geometry 1', 'tail': 'Geometry 2', 'relation': 'followed by'},
#  {'head': 'Geometry 2', 'tail': 'Geometry 1', 'relation': 'follows'},
#  {'head': 'Geometry 1', 'tail': 'Geometry 2', 'relation': 'different from'},
#  {'head': 'Geometry 2', 'tail': 'Geometry 1', 'relation': 'different from'},
#  {'head': 'Geometry 1', 'tail': '1', 'relation': 'part of'},
#  {'head': 'mo del', 'tail': 'protein', 'relation': 'subclass of'},
#  {'head': '33', 'tail': '33', 'relation': 'point in time'},
#  {'head': 'nucleation', 'tail': 'protein', 'relation': 'part of'},
#  {'head': '1995', 'tail': '1995', 'relation': 'point in time'},
#  {'head': 'Hydrophobic Protein Model',
#   'tail': 'Proteins',
#   'relation': 'part of'},
#  {'head': 'Proteins',
#   'tail': 'Hydrophobic Protein Model',
#   'relation': 'has part'},
#  {'head': 'protein', 'tail': 'peptides', 'relation': 'has part'},
#  {'head': 'peptides', 'tail': 'protein', 'relation': 'part of'},
#  {'head': 'Sagnella', 'tail': 'Straub', 'relation': 'student'},
#  {'head': 'Straub', 'tail': 'Sagnella', 'relation': 'student of'},
#  {'head': 'VER rate', 'tail': 'O', 'relation': 'has part'},
#  {'head': 'VER', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'Hochstrasser',
#   'tail': 'U.S.',
#   'relation': 'country of citizenship'},
#  {'head': '84th', 'tail': 'U.S.', 'relation': 'country'},
#  {'head': 'L.A.',
#   'tail': 'L.A.',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': '1999', 'tail': '1999', 'relation': 'point in time'},
#  {'head': '2004', 'tail': '2004', 'relation': 'point in time'},
#  {'head': '2003', 'tail': '2003', 'relation': 'point in time'},
#  {'head': 'Biophysical Journal', 'tail': 'BioFast', 'relation': 'publisher'},
#  {'head': 'myosin II', 'tail': 'myosin V', 'relation': 'different from'},
#  {'head': 'myosin V', 'tail': 'myosin II', 'relation': 'different from'},
#  {'head': 'actin', 'tail': 'myosin', 'relation': 'different from'},
#  {'head': 'myosin', 'tail': 'actin', 'relation': 'different from'},
#  {'head': 'myosin II', 'tail': 'myosin V', 'relation': 'followed by'},
#  {'head': 'myosin', 'tail': 'myosin V', 'relation': 'has part'},
#  {'head': 'myosin V', 'tail': 'myosin', 'relation': 'part of'},
#  {'head': 'myosin II', 'tail': 'Proteins', 'relation': 'subclass of'},
#  {'head': 'myosin V', 'tail': 'Proteins', 'relation': 'subclass of'},
#  {'head': 'National Institute for Medical Research',
#   'tail': 'London',
#   'relation': 'headquarters location'},
#  {'head': 'myosin II', 'tail': 'myosin', 'relation': 'instance of'},
#  {'head': 'φactin', 'tail': 'actin', 'relation': 'part of'},
#  {'head': 'myosin', 'tail': 'MgATP', 'relation': 'has part'},
#  {'head': 'Myosin V', 'tail': 'MgATP', 'relation': 'has part'},
#  {'head': 'myosin II', 'tail': 'myosin VI', 'relation': 'followed by'},
#  {'head': 'L1', 'tail': 'R1', 'relation': 'opposite of'},
#  {'head': 'R1', 'tail': 'L1', 'relation': 'opposite of'},
#  {'head': 'myosin VI', 'tail': 'myosin II', 'relation': 'follows'},
#  {'head': 'V', 'tail': 'myosin', 'relation': 'subclass of'},
#  {'head': 'VI', 'tail': 'myosin', 'relation': 'subclass of'},
#  {'head': 'myosin', 'tail': 'actin', 'relation': 'has part'},
#  {'head': 'actin', 'tail': 'myosin', 'relation': 'part of'},
#  {'head': 'V', 'tail': 'V', 'relation': 'instance of'},
#  {'head': 'bindin g', 'tail': 'myosin', 'relation': 'part of'},
#  {'head': 'myosin', 'tail': 'bindin g', 'relation': 'has part'},
#  {'head': 'actin', 'tail': 'myosin II', 'relation': 'has part'},
#  {'head': 'actin', 'tail': 'V', 'relation': 'has part'},
#  {'head': 'myosin II', 'tail': 'actin', 'relation': 'part of'},
#  {'head': 'V', 'tail': 'actin', 'relation': 'part of'},
#  {'head': '20%', 'tail': '20', 'relation': 'area'},
#  {'head': 'DMR04-25780', 'tail': 'NSF', 'relation': 'parent organization'},
#  {'head': 'P roc Natl Acad Sci U S A',
#   'tail': 'Biophys',
#   'relation': 'instance of'},
#  {'head': 'M.', 'tail': 'M.M.', 'relation': 'said to be the same as'},
#  {'head': 'M.M.', 'tail': 'M.', 'relation': 'said to be the same as'},
#  {'head': 'Journa l of Chemical Physics',
#   'tail': '2003',
#   'relation': 'inception'},
#  {'head': 'Techniques', 'tail': 'P. P.', 'relation': 'part of'},
#  {'head': 'L.A.',
#   'tail': 'M.A.',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'M.A.', 'tail': 'L.A.', 'relation': 'capital'},
#  {'head': 'National Institutes of Health',
#   'tail': 'Bethesda',
#   'relation': 'headquarters location'},
#  {'head': 'II', 'tail': 'myosin', 'relation': 'subclass of'},
#  {'head': 'VI', 'tail': 'myosin', 'relation': 'instance of'},
#  {'head': 'φactin', 'tail': 'actin', 'relation': 'subclass of'},
#  {'head': 'Figure', 'tail': 'figure', 'relation': 'depicts'},
#  {'head': 'Eugene I. Shakhnovich',
#   'tail': 'Harvard University',
#   'relation': 'educated at'},
#  {'head': 'Engrailed Homeodomain',
#   'tail': 'protein',
#   'relation': 'instance of'},
#  {'head': 'Villin', 'tail': 'respec tively', 'relation': 'instance of'},
#  {'head': 'Villin', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'RMSD', 'tail': 'DR MS', 'relation': 'different from'},
#  {'head': 'DR MS', 'tail': 'RMSD', 'relation': 'different from'},
#  {'head': 'H1', 'tail': 'TSE', 'relation': 'part of'},
#  {'head': 'RMSD', 'tail': 'DRMS', 'relation': 'different from'},
#  {'head': 'DRMS', 'tail': 'RMSD', 'relation': 'different from'},
#  {'head': 'H3', 'tail': 'H1', 'relation': 'has part'},
#  {'head': 'H1', 'tail': 'H3', 'relation': 'part of'},
#  {'head': 'Vi llin', 'tail': 'H3', 'relation': 'has part'},
#  {'head': 'W64', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'A64', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'F76', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'MC', 'tail': 'MC', 'relation': 'instance of'},
#  {'head': '1BDD', 'tail': 'PDB', 'relation': 'instance of'},
#  {'head': '4', 'tail': '9', 'relation': 'has part'},
#  {'head': '9', 'tail': '4', 'relation': 'part of'},
#  {'head': '9', 'tail': '9', 'relation': 'has part'},
#  {'head': '9', 'tail': '9', 'relation': 'part of'},
#  {'head': 'd c', 'tail': 'rmsd', 'relation': 'has part'},
#  {'head': 'rmsd', 'tail': 'd c', 'relation': 'part of'},
#  {'head': '1 7', 'tail': '4.4', 'relation': 'part of'},
#  {'head': '4.4', 'tail': '1 7', 'relation': 'has part'},
#  {'head': 'Kluwer Academic Publishers',
#   'tail': 'Dordrecht',
#   'relation': 'headquarters location'},
#  {'head': 'Katholieke Universiteit Leuven',
#   'tail': 'Belgium',
#   'relation': 'country'},
#  {'head': 'peptides', 'tail': 'proteins', 'relation': 'part of'},
#  {'head': 'proteins', 'tail': 'peptides', 'relation': 'has part'},
#  {'head': 'Jahn', 'tail': 'Biochem', 'relation': 'field of work'},
#  {'head': 'Radford', 'tail': 'Biochem', 'relation': 'field of work'},
#  {'head': 'Sci.', 'tail': 'Natl.', 'relation': 'part of'},
#  {'head': 'Natl.', 'tail': 'Sci.', 'relation': 'has part'},
#  {'head': 'Nature', 'tail': '300', 'relation': 'number of articles'},
#  {'head': 'N n', 'tail': 'N l', 'relation': 'has part'},
#  {'head': 'N l', 'tail': 'N n', 'relation': 'part of'},
#  {'head': 'potential', 'tail': 'potential', 'relation': 'is a list of'},
#  {'head': '1HEL', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': '1DKJ', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': '2IHL', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': '1JUG', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'Brownian Dynamics',
#   'tail': 'University of Houston',
#   'relation': 'part of'},
#  {'head': 'UC Berkeley',
#   'tail': 'Berkeley CA',
#   'relation': 'located in the administrative territorial entity'},
#  {'head': 'FRET', 'tail': 'biophysical', 'relation': 'subclass of'},
#  {'head': 'FRET', 'tail': 'FRET', 'relation': 'has part'},
#  {'head': 'FRET', 'tail': 'FRET', 'relation': 'has'},
#  {'head': '101mer', 'tail': '57mer', 'relation': 'opposite of'},
#  {'head': '57mer', 'tail': '101mer', 'relation': 'opposite of'},
#  {'head': 'NaC', 'tail': 'KCl', 'relation': 'has part'},
#  {'head': '43L41', 'tail': 'FRET', 'relation': 'instance of'},
#  {'head': '57L35', 'tail': 'FRET', 'relation': 'instance of'},
#  {'head': '57L35', 'tail': '57C35', 'relation': 'follows'},
#  {'head': '57C35', 'tail': '57L35', 'relation': 'followed by'},
#  {'head': 'Metropolis', 'tail': 'Monte Carlo', 'relation': 'uses'},
#  {'head': 'IHF', 'tail': 'Phoebe Rice', 'relation': 'discoverer or inventor'},
#  {'head': 'SigmaPlot',
#   'tail': 'Systat Sof tware Inc.',
#   'relation': 'developer'},
#  {'head': 'SigmaPlot', 'tail': 'Linden', 'relation': 'discoverer or inventor'},
#  {'head': 'IHF', 'tail': 'IHF', 'relation': 'owned by'},
#  {'head': 'protein purification', 'tail': 'NaCl', 'relation': 'has part'},
#  {'head': '2000', 'tail': '2000', 'relation': 'point in time'},
#  {'head': 'Equilibria', 'tail': 'Equilibria', 'relation': 'has part'},
#  {'head': '1998', 'tail': '1998', 'relation': 'point in time'},
#  {'head': 'M. M.', 'tail': 'M. M.', 'relation': 'different from'},
#  {'head': 'p roteins', 'tail': 'protein', 'relation': 'subclass of'},
#  {'head': 'N', 'tail': 'N', 'relation': 'has part'},
#  {'head': 'Nint', 'tail': 'Vint', 'relation': 'has part'},
#  {'head': 'Vint', 'tail': 'Nint', 'relation': 'part of'},
#  {'head': 'Vint', 'tail': 'Vint', 'relation': 'part of'},
#  {'head': 'Vint', 'tail': 'V', 'relation': 'part of'},
#  {'head': '1pgb', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': '2ptl', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': '1shg', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': '1pks', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': '1fnf9', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': '1csp9', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': '1srl7', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': '1shg6', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': '1pin82ptl30', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': '1pgb31', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': '1fkb35', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'CI2', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'U1A', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'Montal M',
#   'tail': 'Proc Natl Acad Sci USA',
#   'relation': 'member of'},
#  {'head': '3.3', 'tail': '3', 'relation': 'point in time'},
#  {'head': 'Biol', 'tail': 'Biol', 'relation': 'has part'},
#  {'head': 'Biol', 'tail': 'Biol', 'relation': 'part of'},
#  {'head': 'J Mol Biol',
#   'tail': 'Proc Natl Acad Sci USA',
#   'relation': 'publisher'},
#  {'head': 'Qi X', 'tail': 'Proc Natl Acad Sci USA', 'relation': 'member of'},
#  {'head': 'Nat Struct Biol', 'tail': '4', 'relation': 'number of articles'},
#  {'head': 'J Mol Biol', 'tail': 'Nat Struct Biol', 'relation': 'part of'},
#  {'head': 'Nat Struct Biol', 'tail': 'J Mol Biol', 'relation': 'has part'},
#  {'head': 'Proc Natl Acad Sci USA',
#   'tail': 'Biochemistry',
#   'relation': 'has part'},
#  {'head': 'Biochemistry',
#   'tail': 'Proc Natl Acad Sci USA',
#   'relation': 'part of'},
#  {'head': '3D', 'tail': '2D', 'relation': 'opposite of'},
#  {'head': '2D', 'tail': '3D', 'relation': 'opposite of'},
#  {'head': '1D', 'tail': '3D', 'relation': 'opposite of'},
#  {'head': '3D', 'tail': '1D', 'relation': 'opposite of'},
#  {'head': '9', 'tail': '9', 'relation': 'point in time'},
#  {'head': 'Beijing',
#   'tail': 'Beijing',
#   'relation': 'twinned administrative body'},
#  {'head': 'ArcA', 'tail': 'TF', 'relation': 'instance of'},
#  {'head': 'Riggs', 'tail': 'O.G.', 'relation': 'religious order'},
#  {'head': 'Bourgeois', 'tail': 'O.G.', 'relation': 'religious order'},
#  {'head': 'Winter', 'tail': 'O.G.', 'relation': 'religious order'},
#  {'head': 'P.H.', 'tail': 'O.G.', 'relation': 'religious order'},
#  {'head': 'Hu', 'tail': 'China', 'relation': 'country of citizenship'},
#  {'head': 'Cambridge U niversity Press',
#   'tail': 'New York',
#   'relation': 'headquarters location'},
#  {'head': 'Proc Natl Acad Sci US A',
#   'tail': 'Biochemistry',
#   'relation': 'has part'},
#  {'head': 'Biochemistry',
#   'tail': 'Proc Natl Acad Sci US A',
#   'relation': 'part of'},
#  {'head': 'J Mol Biol', 'tail': 'Science', 'relation': 'instance of'},
#  {'head': 'The Biology of Nonspecific DNA Protein Interactions',
#   'tail': 'CRC Press',
#   'relation': 'publisher'},
#  {'head': 'Nucleic Acids Res', 'tail': '34', 'relation': 'number of episodes'},
#  {'head': 'bp', 'tail': 'length', 'relation': 'part of'},
#  {'head': '3D', 'tail': '1D', 'relation': 'follows'},
#  {'head': '1D', 'tail': '3D', 'relation': 'followed by'},
#  {'head': '2', 'tail': '2', 'relation': 'point in time'},
#  {'head': '10-6', 'tail': '10-3', 'relation': 'said to be the same as'},
#  {'head': '10-3', 'tail': '10-6', 'relation': 'said to be the same as'},
#  {'head': 'ligand', 'tail': 'molecule', 'relation': 'part of'},
#  {'head': 'AGBNP1', 'tail': 'AGBNP2', 'relation': 'followed by'},
#  {'head': 'AGBNP2', 'tail': 'AGBNP1', 'relation': 'follows'},
#  {'head': 'atom', 'tail': 'molecule', 'relation': 'part of'},
#  {'head': 'hydr ogen', 'tail': 'hydr ation', 'relation': 'has part'},
#  {'head': 'protein', 'tail': 'atom', 'relation': 'has part'},
#  {'head': 'H', 'tail': 'O', 'relation': 'has part'},
#  {'head': 'O', 'tail': 'H', 'relation': 'has part'},
#  {'head': 'SEV', 'tail': 'SEV', 'relation': 'has part'},
#  {'head': 'SEV', 'tail': 'SEV', 'relation': 'part of'},
#  {'head': 'AGBNP2', 'tail': 'AGBNP2/SEV', 'relation': 'part of'},
#  {'head': 'AGBNP2/SEV', 'tail': 'AGBNP2', 'relation': 'has part'},
#  {'head': 'cdp-1', 'tail': 'conformational', 'relation': 'subclass of'},
#  {'head': 'molecular dynamics', 'tail': 'biomolecules', 'relation': 'studies'},
#  {'head': 'biomolecules',
#   'tail': 'molecular dynamics',
#   'relation': 'studied by'},
#  {'head': 'AGBNP2', 'tail': 'AGBN P2', 'relation': 'different from'},
#  {'head': 'AGBN P2', 'tail': 'AGBNP2', 'relation': 'different from'},
#  {'head': 'AGBNP2', 'tail': 'AGBNP1', 'relation': 'different from'},
#  {'head': 'AGBNP1', 'tail': 'AGBNP2', 'relation': 'different from'},
#  {'head': 'AGB NP2', 'tail': 'AGBNP1', 'relation': 'follows'},
#  {'head': 'AGBNP1', 'tail': 'AGB NP2', 'relation': 'followed by'},
#  {'head': 'aspartate', 'tail': 'protein', 'relation': 'instance of'},
#  {'head': 'oxygen', 'tail': 'hydrogen', 'relation': 'has part'},
#  {'head': 'AGBNP1', 'tail': 'conformational', 'relation': 'instance of'},
#  {'head': '42', 'tail': '42', 'relation': 'part of'},
#  {'head': 'GB', 'tail': 'AGBNP2', 'relation': 'part of'},
#  {'head': 'vdW', 'tail': 'AGBNP2', 'relation': 'part of'},
#  {'head': 'AGBNP2', 'tail': 'GB', 'relation': 'has part'},
#  {'head': 'AGBNP2', 'tail': 'vdW', 'relation': 'has part'},
#  {'head': 'USA', 'tail': 'USA', 'relation': 'country'},
#  {'head': '2009', 'tail': '2009', 'relation': 'point in time'},
#  ...]

# %% [markdown]
# <h1>We will keep multiple entities between same nodes

# %%
allRelations = [res['relation'] for res in final_res]
allRelations = list(set(allRelations))

# %%
len(allRelations)
# Out:
# 79

# %% [markdown]
# <h1> Get the embeddings for those relation ships

# %% [markdown]
# <h2>Using the sentence transformer

# %%
from sentence_transformers import SentenceTransformer

# %%
model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
embeddings = model.encode(allRelations)
print(embeddings.shape)
# Out:
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# (79, 384)

# %%
embd_dict = {rel: embed for rel, embed in zip(allRelations, embeddings)}

# %%
embd_dict.keys()
# Out:
# dict_keys(['country of origin', 'named after', 'different from', 'notable work', 'shares border with', 'subject has role', 'area', 'use', 'located in the administrative territorial entity', 'contains administrative territorial entity', 'number of articles', 'twinned administrative body', 'is a list of', 'practiced by', 'part', 'author', 'subsidiary', 'religious order', 'country', 'father', 'published in', 'capital of', 'publication date', 'facet of', 'date of birth', 'inception', 'student of', 'discoverer or inventor', 'has', 'owned by', 'studies', 'number of participants', 'depicts', 'spouse', 'main subject', 'programming language', 'followed by', 'parent taxon', 'event distance', 'conferred by', 'educated at', 'publisher', 'applies to jurisdiction', 'number of episodes', 'family', 'length', 'has parts of the class', 'work period (start)', 'has cause', 'employer', 'part of', 'location of formation', 'field of this occupation', 'studied by', 'has effect', 'parent organization', 'student', 'member of', 'subclass of', 'instance of', 'located', 'developer', 'owner of', 'uses', 'capital', 'manufacturer', 'country of citizenship', 'said to be the same as', 'taxonomic type', 'part of the series', 'has part', 'based on', 'field of work', 'follows', 'point in time', 'opposite of', 'headquarters location', 'connects with', 'product or material produced'])

# %% [markdown]
# <h1>Using those embeddings peform the KNN algo over them

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
def performOnlineKNN(embed_dict, th):
    centroids = []
    centroids_cluster = []
    centroid_counts = []
    for rel, embed in tqdm_notebook(embed_dict.items(), total= len(embed_dict), desc = "Processing Embeddings: "):
        if len(centroids) == 0:
            centroids.append(embed)
            centroids_cluster.append([rel])
            centroid_counts.append(1)
        else:
            update = False
            for i, cent in enumerate(centroids):
                sim = cosine_similarity(cent.reshape(1, -1), embed.reshape(1, -1))[0][0]
                if sim >= th:
                    centroids[i] = (centroids[i] * centroid_counts[i] + embed) / (centroid_counts[i] + 1)
                    centroid_counts[i] += 1
                    if len(centroids_cluster[i]) == 0:
                        centroids_cluster[i] = [rel]
                    else:
                        centroids_cluster[i].append(rel)
                    update = True
                    break
            if not update:
                centroids.append(embed)
                centroids_cluster.append([rel])
                centroid_counts.append(1)
    return centroids, centroids_cluster

# %%
centroids, centroids_cluster = performOnlineKNN(embd_dict, th=0.7)
# Out:
# <ipython-input-31-d710295bd150>:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for rel, embed in tqdm_notebook(embed_dict.items(), total= len(embed_dict), desc = "Processing Embeddings: "):
# Processing Embeddings:   0%|          | 0/79 [00:00<?, ?it/s]

# %%
centroids_cluster
# Out:
# [['country of origin'],
#  ['named after'],
#  ['different from'],
#  ['notable work'],
#  ['shares border with'],
#  ['subject has role'],
#  ['area'],
#  ['use', 'uses'],
#  ['located in the administrative territorial entity',
#   'contains administrative territorial entity'],
#  ['number of articles'],
#  ['twinned administrative body'],
#  ['is a list of'],
#  ['practiced by'],
#  ['part', 'part of', 'has part'],
#  ['author'],
#  ['subsidiary'],
#  ['religious order'],
#  ['country'],
#  ['father'],
#  ['published in'],
#  ['capital of', 'capital'],
#  ['publication date'],
#  ['facet of'],
#  ['date of birth'],
#  ['inception'],
#  ['student of', 'student'],
#  ['discoverer or inventor'],
#  ['has', 'has cause', 'has effect'],
#  ['owned by', 'owner of'],
#  ['studies', 'studied by'],
#  ['number of participants'],
#  ['depicts'],
#  ['spouse'],
#  ['main subject'],
#  ['programming language'],
#  ['followed by'],
#  ['parent taxon'],
#  ['event distance'],
#  ['conferred by'],
#  ['educated at'],
#  ['publisher'],
#  ['applies to jurisdiction'],
#  ['number of episodes'],
#  ['family'],
#  ['length'],
#  ['has parts of the class'],
#  ['work period (start)'],
#  ['employer'],
#  ['location of formation'],
#  ['field of this occupation', 'field of work'],
#  ['parent organization'],
#  ['member of'],
#  ['subclass of'],
#  ['instance of'],
#  ['located'],
#  ['developer'],
#  ['manufacturer'],
#  ['country of citizenship'],
#  ['said to be the same as'],
#  ['taxonomic type'],
#  ['part of the series'],
#  ['based on'],
#  ['follows'],
#  ['point in time'],
#  ['opposite of'],
#  ['headquarters location'],
#  ['connects with'],
#  ['product or material produced']]

# %% [markdown]
# <h1>Based on the final clusters name the relations and replace the original relations with the cluster names in the dataset

# %%
def getName(embed_dict, centroids_cluster):
    rel_Cluster_Name = {}
    for clust in tqdm_notebook(centroids_cluster, total = len(centroids_cluster), desc = "Finding BestName"):
        most_sim = ""
        max_sum = 0
        if len(clust) == 1:
            rel_Cluster_Name[clust[0]] = clust[0]
            continue
        for ele in clust:
            sim_sum = 0
            for ele2 in clust:
                if ele == ele2: 
                    continue
                sim = cosine_similarity(embed_dict[ele].reshape(1, -1), embed_dict[ele2].reshape(1, -1))[0][0]
                sim_sum += sim
            if  max_sum < sim_sum:
                max_sum = sim_sum
                most_sim = ele
        for ele in clust:
            rel_Cluster_Name[ele] = most_sim
             
    return rel_Cluster_Name

# %%
rel_Cluster_Name = getName(embd_dict, centroids_cluster)
rel_Cluster_Name
# Out:
# <ipython-input-34-0ee9281c2ce6>:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for clust in tqdm_notebook(centroids_cluster, total = len(centroids_cluster), desc = "Finding BestName"):
# Finding BestName:   0%|          | 0/68 [00:00<?, ?it/s]
# {'country of origin': 'country of origin',
#  'named after': 'named after',
#  'different from': 'different from',
#  'notable work': 'notable work',
#  'shares border with': 'shares border with',
#  'subject has role': 'subject has role',
#  'area': 'area',
#  'use': 'use',
#  'uses': 'use',
#  'located in the administrative territorial entity': 'located in the administrative territorial entity',
#  'contains administrative territorial entity': 'located in the administrative territorial entity',
#  'number of articles': 'number of articles',
#  'twinned administrative body': 'twinned administrative body',
#  'is a list of': 'is a list of',
#  'practiced by': 'practiced by',
#  'part': 'part',
#  'part of': 'part',
#  'has part': 'part',
#  'author': 'author',
#  'subsidiary': 'subsidiary',
#  'religious order': 'religious order',
#  'country': 'country',
#  'father': 'father',
#  'published in': 'published in',
#  'capital of': 'capital of',
#  'capital': 'capital of',
#  'publication date': 'publication date',
#  'facet of': 'facet of',
#  'date of birth': 'date of birth',
#  'inception': 'inception',
#  'student of': 'student of',
#  'student': 'student of',
#  'discoverer or inventor': 'discoverer or inventor',
#  'has': 'has cause',
#  'has cause': 'has cause',
#  'has effect': 'has cause',
#  'owned by': 'owned by',
#  'owner of': 'owned by',
#  'studies': 'studies',
#  'studied by': 'studies',
#  'number of participants': 'number of participants',
#  'depicts': 'depicts',
#  'spouse': 'spouse',
#  'main subject': 'main subject',
#  'programming language': 'programming language',
#  'followed by': 'followed by',
#  'parent taxon': 'parent taxon',
#  'event distance': 'event distance',
#  'conferred by': 'conferred by',
#  'educated at': 'educated at',
#  'publisher': 'publisher',
#  'applies to jurisdiction': 'applies to jurisdiction',
#  'number of episodes': 'number of episodes',
#  'family': 'family',
#  'length': 'length',
#  'has parts of the class': 'has parts of the class',
#  'work period (start)': 'work period (start)',
#  'employer': 'employer',
#  'location of formation': 'location of formation',
#  'field of this occupation': 'field of this occupation',
#  'field of work': 'field of this occupation',
#  'parent organization': 'parent organization',
#  'member of': 'member of',
#  'subclass of': 'subclass of',
#  'instance of': 'instance of',
#  'located': 'located',
#  'developer': 'developer',
#  'manufacturer': 'manufacturer',
#  'country of citizenship': 'country of citizenship',
#  'said to be the same as': 'said to be the same as',
#  'taxonomic type': 'taxonomic type',
#  'part of the series': 'part of the series',
#  'based on': 'based on',
#  'follows': 'follows',
#  'point in time': 'point in time',
#  'opposite of': 'opposite of',
#  'headquarters location': 'headquarters location',
#  'connects with': 'connects with',
#  'product or material produced': 'product or material produced'}

# %%
rel_Cluster_Name
# Out:
# {'country of origin': 'country of origin',
#  'named after': 'named after',
#  'different from': 'different from',
#  'notable work': 'notable work',
#  'shares border with': 'shares border with',
#  'subject has role': 'subject has role',
#  'area': 'area',
#  'use': 'use',
#  'uses': 'use',
#  'located in the administrative territorial entity': 'located in the administrative territorial entity',
#  'contains administrative territorial entity': 'located in the administrative territorial entity',
#  'number of articles': 'number of articles',
#  'twinned administrative body': 'twinned administrative body',
#  'is a list of': 'is a list of',
#  'practiced by': 'practiced by',
#  'part': 'part',
#  'part of': 'part',
#  'has part': 'part',
#  'author': 'author',
#  'subsidiary': 'subsidiary',
#  'religious order': 'religious order',
#  'country': 'country',
#  'father': 'father',
#  'published in': 'published in',
#  'capital of': 'capital of',
#  'capital': 'capital of',
#  'publication date': 'publication date',
#  'facet of': 'facet of',
#  'date of birth': 'date of birth',
#  'inception': 'inception',
#  'student of': 'student of',
#  'student': 'student of',
#  'discoverer or inventor': 'discoverer or inventor',
#  'has': 'has cause',
#  'has cause': 'has cause',
#  'has effect': 'has cause',
#  'owned by': 'owned by',
#  'owner of': 'owned by',
#  'studies': 'studies',
#  'studied by': 'studies',
#  'number of participants': 'number of participants',
#  'depicts': 'depicts',
#  'spouse': 'spouse',
#  'main subject': 'main subject',
#  'programming language': 'programming language',
#  'followed by': 'followed by',
#  'parent taxon': 'parent taxon',
#  'event distance': 'event distance',
#  'conferred by': 'conferred by',
#  'educated at': 'educated at',
#  'publisher': 'publisher',
#  'applies to jurisdiction': 'applies to jurisdiction',
#  'number of episodes': 'number of episodes',
#  'family': 'family',
#  'length': 'length',
#  'has parts of the class': 'has parts of the class',
#  'work period (start)': 'work period (start)',
#  'employer': 'employer',
#  'location of formation': 'location of formation',
#  'field of this occupation': 'field of this occupation',
#  'field of work': 'field of this occupation',
#  'parent organization': 'parent organization',
#  'member of': 'member of',
#  'subclass of': 'subclass of',
#  'instance of': 'instance of',
#  'located': 'located',
#  'developer': 'developer',
#  'manufacturer': 'manufacturer',
#  'country of citizenship': 'country of citizenship',
#  'said to be the same as': 'said to be the same as',
#  'taxonomic type': 'taxonomic type',
#  'part of the series': 'part of the series',
#  'based on': 'based on',
#  'follows': 'follows',
#  'point in time': 'point in time',
#  'opposite of': 'opposite of',
#  'headquarters location': 'headquarters location',
#  'connects with': 'connects with',
#  'product or material produced': 'product or material produced'}

# %% [markdown]
# <h1>Finally make a csv with the columns: head, tail, original relationship, cluster name

# %%
originalEntitiesEmbd = model.encode(originalEntities)
orgEntEm_dict = {orgEnt.lower().replace(" ", "").strip(): orgEmbed for orgEnt, orgEmbed in zip(originalEntities,originalEntitiesEmbd)}
# orgEntEm_dict
# Out:
# Batches:   0%|          | 0/2416 [00:00<?, ?it/s]

# %%
import pandas as pd
# columns to make: head, tail, orignal relations, cluster name and along with that we also need the embeddings of the relation and the embedding of head and tail
data_df = {
    "head": [],
    "tail":[],
    "relation":[],
    "relationCluster": [],
    "headType":[],
    "tailType":[],
    "headEmbed":[],
    "tailEmbed":[],
    "relEmbed":[]
}
# entityType_dict
# final_res
for res in tqdm_notebook(final_res, desc = "Making the final Df", total = len(final_res)):
    data_df['head'].append(res['head'])
    data_df['tail'].append(res['tail'])
    data_df['relation'].append(res['relation'])
    data_df['relationCluster'].append(rel_Cluster_Name[res['relation']])
    data_df['headType'].append(entityType_dict[res['head'].lower().replace(" ", "").strip()])
    data_df['tailType'].append(entityType_dict[res['tail'].lower().replace(" ", "").strip()])
    data_df['headEmbed'].append(str(orgEntEm_dict[res['head'].lower().replace(" ", "").strip()]))
    data_df['tailEmbed'].append(str(orgEntEm_dict[res['tail'].lower().replace(" ", "").strip()]))
    data_df['relEmbed'].append(str(embd_dict[res['relation']]))

data_df = pd.DataFrame(data_df)
data_df
# Out:
# <ipython-input-38-b6615e34f64d>:16: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for res in tqdm_notebook(final_res, desc = "Making the final Df", total = len(final_res)):
# Making the final Df:   0%|          | 0/1592 [00:00<?, ?it/s]
#                      head                 tail            relation  \
# 0                 binding              binding                 use
# 1                molecule                  RNA            has part
# 2                     RNA           nucleotide            has part
# 3     Mohamed A. Marahiel  Philipps University            employer
# 4             recognition          recognition         instance of
# ...                   ...                  ...                 ...
# 1587                 1KFM              protein         instance of
# 1588                 1QJ9              protein         instance of
# 1589                 1LSX              protein         instance of
# 1590  Biophysical Journal                   79  number of articles
# 1591  Biophysical Journal                   88  number of articles
#
#          relationCluster  headType  tailType  \
# 0                    use    PERSON    PERSON
# 1                   part       ORG       ORG
# 2                   part       ORG    PERSON
# 3               employer    PERSON       ORG
# 4            instance of       ORG       ORG
# ...                  ...       ...       ...
# 1587         instance of    PERSON       GPE
# 1588         instance of  CARDINAL       GPE
# 1589         instance of      DATE       GPE
# 1590  number of articles       ORG  CARDINAL
# 1591  number of articles       ORG  CARDINAL
#
#                                               headEmbed  \
# 0     [-1.21414684e-01  7.70534948e-02 -6.98211342e-...
# 1     [-3.25336270e-02 -4.65905480e-02 -4.65750284e-...
# 2     [-2.83921994e-02 -4.77526076e-02 -2.52587777e-...
# 3     [ 2.43127402e-02  1.21844962e-01 -4.82097529e-...
# 4     [-4.66626249e-02  3.92468609e-02 -1.46743702e-...
# ...                                                 ...
# 1587  [-4.20423038e-03  4.03800830e-02 -5.87142520e-...
# 1588  [-9.14737508e-02 -2.53125317e-02 -1.44129246e-...
# 1589  [-6.63179606e-02  2.36366652e-02  1.50013287e-...
# 1590  [-7.37022981e-02 -3.67033258e-02 -1.12545015e-...
# 1591  [-7.37022981e-02 -3.67033258e-02 -1.12545015e-...
#
#                                               tailEmbed  \
# 0     [-1.21414684e-01  7.70534948e-02 -6.98211342e-...
# 1     [-2.83921994e-02 -4.77526076e-02 -2.52587777e-...
# 2     [-6.87153712e-02 -3.47657092e-02 -5.22661991e-...
# 3     [-1.81916431e-02  4.98085357e-02 -4.74214414e-...
# 4     [-4.66626249e-02  3.92468609e-02 -1.46743702e-...
# ...                                                 ...
# 1587  [-5.44746667e-02 -7.03664273e-02 -1.68157909e-...
# 1588  [-5.44746667e-02 -7.03664273e-02 -1.68157909e-...
# 1589  [-5.44746667e-02 -7.03664273e-02 -1.68157909e-...
# 1590  [ 2.68745739e-02  1.45227686e-01 -6.88864291e-...
# 1591  [-1.09181609e-02  1.09446011e-01 -7.52167776e-...
#
#                                                relEmbed
# 0     [-4.45322357e-02  4.27974947e-02 -4.77293991e-...
# 1     [ 2.79611517e-02  8.10583457e-02  9.62299332e-...
# 2     [ 2.79611517e-02  8.10583457e-02  9.62299332e-...
# 3     [-8.25185329e-02  7.37527981e-02  1.93586424e-...
# 4     [-1.19809937e-02 -7.29214912e-03  3.41963544e-...
# ...                                                 ...
# 1587  [-1.19809937e-02 -7.29214912e-03  3.41963544e-...
# 1588  [-1.19809937e-02 -7.29214912e-03  3.41963544e-...
# 1589  [-1.19809937e-02 -7.29214912e-03  3.41963544e-...
# 1590  [ 6.02299124e-02  1.41815487e-02 -2.53492631e-...
# 1591  [ 6.02299124e-02  1.41815487e-02 -2.53492631e-...
#
# [1592 rows x 9 columns]

# %%
from IPython.display import FileLink
data_df.to_csv("Biology_.csv",index = False)
link = FileLink('Biology_.csv')

# %%
link
# Out:
# /kaggle/working/Biology_.csv
